# %% [markdown]
# # Models Testing

# %%
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torch.nn.modules.activation import LeakyReLU

# %%
# Set seeds
torch.manual_seed(0)
np.random.seed(0)

# %%
synthetic_calls_path = '../data/binom_synthetic_calls.csv'
synthetic_puts_path = '../data/binom_synthetic_puts.csv'

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    
    return df

# %%
synthetic_calls = pd.read_csv(synthetic_calls_path, index_col=0)
synthetic_puts = pd.read_csv(synthetic_puts_path, index_col=0)

synthetic_calls = reduce_mem_usage(synthetic_calls)
synthetic_puts = reduce_mem_usage(synthetic_puts)

# %%
synthetic_options = pd.concat([synthetic_calls, synthetic_puts], axis=0)
synthetic_options = shuffle(synthetic_options, random_state=0)
synthetic_options = synthetic_options.reset_index()
synthetic_options = synthetic_options.drop('index', axis=1)

# %% [markdown]
# # Preprocessing

# %%
synthetic_options = pd.get_dummies(synthetic_options, prefix='', prefix_sep='')

# %%
input_sc = StandardScaler()
output_sc = StandardScaler()
input_data = input_sc.fit_transform(synthetic_options.drop('Option Price', axis=1))
output_data = output_sc.fit_transform(synthetic_options['Option Price'].values.reshape(-1, 1))

train_size = 0.8
val_size = 0.1

last_train_idx = int(np.round(len(input_data) * train_size))
last_val_idx = last_train_idx + int(np.round(len(input_data) * val_size))

X_train = input_data[0:last_train_idx]
X_val = input_data[last_train_idx:last_val_idx]
X_test = input_data[last_val_idx:]

y_train = output_data[0:last_train_idx]
y_val = output_data[last_train_idx:last_val_idx]
y_test = output_data[last_val_idx:]

# %%
X_train = Variable(torch.Tensor(X_train))
X_val = Variable(torch.Tensor(X_val))
X_test = Variable(torch.Tensor(X_test))

y_train = Variable(torch.Tensor(y_train))
y_val = Variable(torch.Tensor(y_val))
y_test = Variable(torch.Tensor(y_test))

# %% [markdown]
# # Model

# %%
CUDA = torch.cuda.is_available()
device = 'cuda:0' if CUDA else 'cpu'

# %%
class ResBlock(nn.Module):

  def __init__(self, module):
    super(ResBlock, self).__init__()
    self.module = module

  def forward(self, x):
    return self.module(x) + x

# %%
class HiddenLayer(nn.Module):

  def __init__(self, layer_size, act_fn):
      super(HiddenLayer, self).__init__()
      
      if act_fn == 'ReLU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.ReLU())
      elif act_fn == 'LeakyReLU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.LeakyReLU())
      elif act_fn == 'ELU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.ELU())
    
  def forward(self, x):
    return self.layer(x)

# %%
class Net(nn.Module):

  def __init__(self, input_size, output_size, hidden_size, num_layers, act_fn):
    super(Net, self).__init__()
    self.input_size = input_size
    self.output_size = output_size
    self.hidden_size = hidden_size

    if act_fn == 'ReLU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.ReLU())
    elif act_fn == 'LeakyReLU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.LeakyReLU())
    elif act_fn == 'ELU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.ELU())

    self.hidden_layers_list = []

    for i in range(num_layers // 2):
      self.hidden_layers_list.append(
          ResBlock(
            nn.Sequential(
                HiddenLayer(self.hidden_size, act_fn),
                HiddenLayer(self.hidden_size, act_fn)
            )
        )
      )

    self.hidden_layers = nn.Sequential(*self.hidden_layers_list)

    self.net = nn.Sequential(
        self.initial_layer,
        self.hidden_layers,
        nn.Linear(self.hidden_size, self.output_size)
    )
  
  def forward(self, x):
    return self.net(x)

# %%
def init_weights(m, init_m: str):

  @torch.no_grad()
  def init_uniform(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.uniform_(m.weight)
      m.bias.data.fill_(0.01)

  @torch.no_grad()
  def init_normal(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.normal_(m.weight)
      m.bias.data.fill_(0.01)

  @torch.no_grad()
  def init_xuniform(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.xavier_uniform_(m.weight)
      m.bias.data.fill_(0.01)

  @torch.no_grad()
  def init_xnormal(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.xavier_normal_(m.weight)
      m.bias.data.fill_(0.01)

  if init_m == 'uniform':
    m.apply(init_uniform)
  elif init_m == 'normal':
    m.apply(init_normal)
  elif init_m == 'xaiver uniform':
    m.apply(init_xuniform)
  elif init_m == 'xavier normal':
    m.apply(init_xnormal)

# %% [markdown]
# # Best models from cross validation

# %%
best_models = [
               {'n_hidden': 400, 'n_layers': 8, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 4, 'act_fun': 'ReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 4, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 6, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 8, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'}
]

# %% [markdown]
# # Training

# %%
input_size = 7
output_size = 1
batch_size = 1208
epochs = 125
lr = 1e-4

loss_fn = nn.MSELoss()

# %%
class OptDataset(Dataset):

  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __getitem__(self, idx):
    return self.X[idx], self.y[idx]

  def __len__(self):
    return len(self.X)

# %%
def evaluate(model, loss_fn, X, y):
  model.eval()
  with torch.no_grad():
    out = model(X.to(device))
    loss = loss_fn(out, y.to(device))
    return loss.item()

# %%
def mape_loss(y_pred, y):
  return sum([np.abs(y_i - hy_i) / y_i for y_i, hy_i in zip(y_pred, y)]) / len(y_pred)

# %%
def get_mape_loss(model, X, y):
  model.eval()
  with torch.no_grad():
    out = model(X.to(device))
    loss = mape_loss(
        out.squeeze().cpu().detach().numpy(), 
        y.squeeze().cpu().detach().numpy())
    return loss

# %%
def test_models(
  models_dict,
  epochs,
  batch_size,
  X_train,
  y_train,
  X_val,
  y_val,
  X_test,
  y_test,
  loss_fn
):
  testing_results = pd.DataFrame(columns=
                               ['hidden_size',
                                'n_layers',
                                'act_fun',
                                'init_methods',
                                'mean_val_result',
                                'std_val_result',
                                'test_mse',
                                'test_mae',
                                'test_rmse',
                                'test_mape'])

  for model_dict in models_dict:
    model = Net(input_size,
                output_size, 
                model_dict['n_hidden'], 
                model_dict['n_layers'], 
                model_dict['act_fun']).to(device)
    init_weights(model, model_dict['init_method'])
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    validation_losses = []
    test_res = {
        'hidden_size': model_dict['n_hidden'],
        'n_layers': model_dict['n_layers'],
        'act_fun': model_dict['act_fun'],
        'init_methods': model_dict['init_method']
    }

    print('Model: ', test_res)

    for epoch in range(epochs):
      model.train()
      total_loss = 0
      start_time = time.time()
      i = 0

      for batch, batch_labels in DataLoader(OptDataset(X_train, y_train), batch_size):
        out = model(batch.to(device))
        optimizer.zero_grad()

        loss = loss_fn(out, batch_labels.to(device))
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        if i > 0 and i % 25 == 0:
          avg_loss = total_loss / 50
          elapsed = time.time() - start_time
          print('| Epoch {:3d} | {:5d}/{:5d} batches | lr {:2.5f} | ms/batch {:5.2f} | '
                  'loss {:5.8f}'.format(
              epoch, i, len(X_train) // batch_size+1, lr, elapsed * 1000 / 50,
              avg_loss))
          start_time = time.time()
          total_loss = 0
        
        i += 1

      validation_losses.append(evaluate(model, loss_fn, X_val, y_val))
    
    mse_test = evaluate(model, loss_fn, X_test, y_test)
    mae_loss = nn.L1Loss()
    mae_test = evaluate(model, mae_loss, X_test, y_test)
    mape_test = get_mape_loss(model, X_test, y_test)
    validation_losses = np.array(validation_losses)
    test_res['mean_val_result'] = validation_losses.mean()
    test_res['std_val_result'] = validation_losses.std()
    test_res['test_mse'] = mse_test
    test_res['test_mae'] = mae_test
    test_res['test_rmse'] = np.sqrt(mse_test)
    test_res['test_mape'] = mape_test

    testing_results = testing_results.append(test_res, ignore_index=True)

  return testing_results

# %%
testing_results = test_models(best_models,
            epochs,
            batch_size,
             X_train,
            y_train,
            X_val,
            y_val,
            X_test,
            y_test,
            loss_fn)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# | Epoch  41 |   325/  401 batches | lr 0.00010 | ms/batch  5.70 | loss 0.00000768
# | Epoch  41 |   350/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000433
# | Epoch  41 |   375/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000587
# | Epoch  42 |    25/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00000563
# | Epoch  42 |    50/  401 batches | lr 0.00010 | ms/batch  6.49 | loss 0.00000378
# | Epoch  42 |    75/  401 batches | lr 0.00010 | ms/batch  5.67 | loss 0.00000549
# | Epoch  42 |   100/  401 batches | lr 0.00010 | ms/batch  6.46 | loss 0.00001569
# | Epoch  42 |   125/  401 batches | lr 0.00010 | ms/batch  6.41 | loss 0.00000594
# | Epoch  42 |   150/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000368
# | Epoch  42 |   175/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00005037
# | Epoch  42 |   200/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00000891
# | Epoch  42 |   225/  401 batches | lr 0.00010 | ms/batch  6.73 | loss 0.00000623
# | Epoch  42 |   250/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000458
# | Epoch  42 |   275/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00000379
# | Epoch  42 |   300/  401 batches | lr 0.00010 | ms/batch  7.07 | loss 0.00000633
# | Epoch  42 |   325/  401 batches | lr 0.00010 | ms/batch  5.47 | loss 0.00001007
# | Epoch  42 |   350/  401 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00000478
# | Epoch  42 |   375/  401 batches | lr 0.00010 | ms/batch  6.31 | loss 0.00004348
# | Epoch  43 |    25/  401 batches | lr 0.00010 | ms/batch  6.53 | loss 0.00000821
# | Epoch  43 |    50/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00000367
# | Epoch  43 |    75/  401 batches | lr 0.00010 | ms/batch  5.31 | loss 0.00000431
# | Epoch  43 |   100/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000580
# | Epoch  43 |   125/  401 batches | lr 0.00010 | ms/batch  6.49 | loss 0.00000703
# | Epoch  43 |   150/  401 batches | lr 0.00010 | ms/batch  5.52 | loss 0.00000527
# | Epoch  43 |   175/  401 batches | lr 0.00010 | ms/batch  6.65 | loss 0.00000842
# | Epoch  43 |   200/  401 batches | lr 0.00010 | ms/batch  6.53 | loss 0.00002559
# | Epoch  43 |   225/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00002979
# | Epoch  43 |   250/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000482
# | Epoch  43 |   275/  401 batches | lr 0.00010 | ms/batch  6.38 | loss 0.00000401
# | Epoch  43 |   300/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000769
# | Epoch  43 |   325/  401 batches | lr 0.00010 | ms/batch  5.70 | loss 0.00001448
# | Epoch  43 |   350/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00001081
# | Epoch  43 |   375/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00000969
# | Epoch  44 |    25/  401 batches | lr 0.00010 | ms/batch  6.40 | loss 0.00000320
# | Epoch  44 |    50/  401 batches | lr 0.00010 | ms/batch  6.53 | loss 0.00001451
# | Epoch  44 |    75/  401 batches | lr 0.00010 | ms/batch  5.34 | loss 0.00000966
# | Epoch  44 |   100/  401 batches | lr 0.00010 | ms/batch  7.10 | loss 0.00000766
# | Epoch  44 |   125/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00001534
# | Epoch  44 |   150/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00000517
# | Epoch  44 |   175/  401 batches | lr 0.00010 | ms/batch  6.76 | loss 0.00001067
# | Epoch  44 |   200/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00001369
# | Epoch  44 |   225/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00003456
# | Epoch  44 |   250/  401 batches | lr 0.00010 | ms/batch  5.85 | loss 0.00000952
# | Epoch  44 |   275/  401 batches | lr 0.00010 | ms/batch  6.64 | loss 0.00000492
# | Epoch  44 |   300/  401 batches | lr 0.00010 | ms/batch  5.43 | loss 0.00000710
# | Epoch  44 |   325/  401 batches | lr 0.00010 | ms/batch  7.31 | loss 0.00001324
# | Epoch  44 |   350/  401 batches | lr 0.00010 | ms/batch  6.40 | loss 0.00001062
# | Epoch  44 |   375/  401 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00000861
# | Epoch  45 |    25/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000366
# | Epoch  45 |    50/  401 batches | lr 0.00010 | ms/batch  5.40 | loss 0.00002132
# | Epoch  45 |    75/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00001555
# | Epoch  45 |   100/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000545
# | Epoch  45 |   125/  401 batches | lr 0.00010 | ms/batch  6.56 | loss 0.00000564
# | Epoch  45 |   150/  401 batches | lr 0.00010 | ms/batch  5.42 | loss 0.00000914
# | Epoch  45 |   175/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00001369
# | Epoch  45 |   200/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00002132
# | Epoch  45 |   225/  401 batches | lr 0.00010 | ms/batch  5.46 | loss 0.00001407
# | Epoch  45 |   250/  401 batches | lr 0.00010 | ms/batch  6.41 | loss 0.00000541
# | Epoch  45 |   275/  401 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00000391
# | Epoch  45 |   300/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000570
# | Epoch  45 |   325/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00002168
# | Epoch  45 |   350/  401 batches | lr 0.00010 | ms/batch  6.48 | loss 0.00001294
# | Epoch  45 |   375/  401 batches | lr 0.00010 | ms/batch  6.66 | loss 0.00000583
# | Epoch  46 |    25/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00001800
# | Epoch  46 |    50/  401 batches | lr 0.00010 | ms/batch  6.39 | loss 0.00001010
# | Epoch  46 |    75/  401 batches | lr 0.00010 | ms/batch  5.46 | loss 0.00001164
# | Epoch  46 |   100/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00001177
# | Epoch  46 |   125/  401 batches | lr 0.00010 | ms/batch  6.40 | loss 0.00001257
# | Epoch  46 |   150/  401 batches | lr 0.00010 | ms/batch  5.45 | loss 0.00000680
# | Epoch  46 |   175/  401 batches | lr 0.00010 | ms/batch  6.55 | loss 0.00000724
# | Epoch  46 |   200/  401 batches | lr 0.00010 | ms/batch  5.58 | loss 0.00001669
# | Epoch  46 |   225/  401 batches | lr 0.00010 | ms/batch  6.40 | loss 0.00000850
# | Epoch  46 |   250/  401 batches | lr 0.00010 | ms/batch  6.73 | loss 0.00000489
# | Epoch  46 |   275/  401 batches | lr 0.00010 | ms/batch  6.51 | loss 0.00001760
# | Epoch  46 |   300/  401 batches | lr 0.00010 | ms/batch  5.62 | loss 0.00000729
# | Epoch  46 |   325/  401 batches | lr 0.00010 | ms/batch  6.52 | loss 0.00000924
# | Epoch  46 |   350/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000751
# | Epoch  46 |   375/  401 batches | lr 0.00010 | ms/batch  5.48 | loss 0.00001325
# | Epoch  47 |    25/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00002163
# | Epoch  47 |    50/  401 batches | lr 0.00010 | ms/batch  5.36 | loss 0.00000879
# | Epoch  47 |    75/  401 batches | lr 0.00010 | ms/batch  6.44 | loss 0.00000411
# | Epoch  47 |   100/  401 batches | lr 0.00010 | ms/batch  6.85 | loss 0.00000842
# | Epoch  47 |   125/  401 batches | lr 0.00010 | ms/batch  5.34 | loss 0.00002856
# | Epoch  47 |   150/  401 batches | lr 0.00010 | ms/batch  6.44 | loss 0.00002127
# | Epoch  47 |   175/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00000963
# | Epoch  47 |   200/  401 batches | lr 0.00010 | ms/batch  5.43 | loss 0.00001120
# | Epoch  47 |   225/  401 batches | lr 0.00010 | ms/batch  6.51 | loss 0.00000991
# | Epoch  47 |   250/  401 batches | lr 0.00010 | ms/batch  6.46 | loss 0.00000448
# | Epoch  47 |   275/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000382
# | Epoch  47 |   300/  401 batches | lr 0.00010 | ms/batch  5.35 | loss 0.00000881
# | Epoch  47 |   325/  401 batches | lr 0.00010 | ms/batch  6.88 | loss 0.00001006
# | Epoch  47 |   350/  401 batches | lr 0.00010 | ms/batch  5.73 | loss 0.00001158
# | Epoch  47 |   375/  401 batches | lr 0.00010 | ms/batch  6.91 | loss 0.00000534
# | Epoch  48 |    25/  401 batches | lr 0.00010 | ms/batch  7.12 | loss 0.00002195
# | Epoch  48 |    50/  401 batches | lr 0.00010 | ms/batch  5.44 | loss 0.00002744
# | Epoch  48 |    75/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000546
# | Epoch  48 |   100/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00000463
# | Epoch  48 |   125/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00000337
# | Epoch  48 |   150/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000433
# | Epoch  48 |   175/  401 batches | lr 0.00010 | ms/batch  7.19 | loss 0.00000611
# | Epoch  48 |   200/  401 batches | lr 0.00010 | ms/batch  5.61 | loss 0.00002453
# | Epoch  48 |   225/  401 batches | lr 0.00010 | ms/batch  6.82 | loss 0.00000581
# | Epoch  48 |   250/  401 batches | lr 0.00010 | ms/batch  7.24 | loss 0.00000622
# | Epoch  48 |   275/  401 batches | lr 0.00010 | ms/batch  5.60 | loss 0.00001210
# | Epoch  48 |   300/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00001362
# | Epoch  48 |   325/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000965
# | Epoch  48 |   350/  401 batches | lr 0.00010 | ms/batch  5.42 | loss 0.00001325
# | Epoch  48 |   375/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000713
# | Epoch  49 |    25/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00000949
# | Epoch  49 |    50/  401 batches | lr 0.00010 | ms/batch  5.53 | loss 0.00000583
# | Epoch  49 |    75/  401 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00001322
# | Epoch  49 |   100/  401 batches | lr 0.00010 | ms/batch  5.47 | loss 0.00001293
# | Epoch  49 |   125/  401 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00000508
# | Epoch  49 |   150/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000712
# | Epoch  49 |   175/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000845
# | Epoch  49 |   200/  401 batches | lr 0.00010 | ms/batch  5.39 | loss 0.00003484
# | Epoch  49 |   225/  401 batches | lr 0.00010 | ms/batch  6.48 | loss 0.00000551
# | Epoch  49 |   250/  401 batches | lr 0.00010 | ms/batch  6.88 | loss 0.00000572
# | Epoch  49 |   275/  401 batches | lr 0.00010 | ms/batch  5.28 | loss 0.00000382
# | Epoch  49 |   300/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00000528
# | Epoch  49 |   325/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00002109
# | Epoch  49 |   350/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00001120
# | Epoch  49 |   375/  401 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00000741
# | Epoch  50 |    25/  401 batches | lr 0.00010 | ms/batch  5.45 | loss 0.00000898
# | Epoch  50 |    50/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00000458
# | Epoch  50 |    75/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00001698
# | Epoch  50 |   100/  401 batches | lr 0.00010 | ms/batch  5.86 | loss 0.00001104
# | Epoch  50 |   125/  401 batches | lr 0.00010 | ms/batch  6.64 | loss 0.00000532
# | Epoch  50 |   150/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00000733
# | Epoch  50 |   175/  401 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00003114
# | Epoch  50 |   200/  401 batches | lr 0.00010 | ms/batch  5.27 | loss 0.00002035
# | Epoch  50 |   225/  401 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00000842
# | Epoch  50 |   250/  401 batches | lr 0.00010 | ms/batch  5.75 | loss 0.00000371
# | Epoch  50 |   275/  401 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00000410
# | Epoch  50 |   300/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000755
# | Epoch  50 |   325/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00000652
# | Epoch  50 |   350/  401 batches | lr 0.00010 | ms/batch  5.47 | loss 0.00001082
# | Epoch  50 |   375/  401 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00000412
# | Epoch  51 |    25/  401 batches | lr 0.00010 | ms/batch  5.60 | loss 0.00001529
# | Epoch  51 |    50/  401 batches | lr 0.00010 | ms/batch  6.48 | loss 0.00003684
# | Epoch  51 |    75/  401 batches | lr 0.00010 | ms/batch  6.55 | loss 0.00000488
# | Epoch  51 |   100/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000410
# | Epoch  51 |   125/  401 batches | lr 0.00010 | ms/batch  6.30 | loss 0.00000344
# | Epoch  51 |   150/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000439
# | Epoch  51 |   175/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00000940
# | Epoch  51 |   200/  401 batches | lr 0.00010 | ms/batch  5.37 | loss 0.00001351
# | Epoch  51 |   225/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00000632
# | Epoch  51 |   250/  401 batches | lr 0.00010 | ms/batch  6.71 | loss 0.00000464
# | Epoch  51 |   275/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00000650
# | Epoch  51 |   300/  401 batches | lr 0.00010 | ms/batch  6.71 | loss 0.00001638
# | Epoch  51 |   325/  401 batches | lr 0.00010 | ms/batch  6.48 | loss 0.00000900
# | Epoch  51 |   350/  401 batches | lr 0.00010 | ms/batch  5.53 | loss 0.00001055
# | Epoch  51 |   375/  401 batches | lr 0.00010 | ms/batch  6.29 | loss 0.00000514
# | Epoch  52 |    25/  401 batches | lr 0.00010 | ms/batch  5.60 | loss 0.00002377
# | Epoch  52 |    50/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00001044
# | Epoch  52 |    75/  401 batches | lr 0.00010 | ms/batch  6.52 | loss 0.00001067
# | Epoch  52 |   100/  401 batches | lr 0.00010 | ms/batch  5.85 | loss 0.00000797
# | Epoch  52 |   125/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00000302
# | Epoch  52 |   150/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00000382
# | Epoch  52 |   175/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00000371
# | Epoch  52 |   200/  401 batches | lr 0.00010 | ms/batch  6.44 | loss 0.00007332
# | Epoch  52 |   225/  401 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00003238
# | Epoch  52 |   250/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00000661
# | Epoch  52 |   275/  401 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00000359
# | Epoch  52 |   300/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000400
# | Epoch  52 |   325/  401 batches | lr 0.00010 | ms/batch  5.43 | loss 0.00000418
# | Epoch  52 |   350/  401 batches | lr 0.00010 | ms/batch  6.85 | loss 0.00000315
# | Epoch  52 |   375/  401 batches | lr 0.00010 | ms/batch  6.94 | loss 0.00000409
# | Epoch  53 |    25/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000536
# | Epoch  53 |    50/  401 batches | lr 0.00010 | ms/batch  6.38 | loss 0.00000332
# | Epoch  53 |    75/  401 batches | lr 0.00010 | ms/batch  5.33 | loss 0.00000412
# | Epoch  53 |   100/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000396
# | Epoch  53 |   125/  401 batches | lr 0.00010 | ms/batch  6.34 | loss 0.00000341
# | Epoch  53 |   150/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00001167
# | Epoch  53 |   175/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00001417
# | Epoch  53 |   200/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00001811
# | Epoch  53 |   225/  401 batches | lr 0.00010 | ms/batch  5.38 | loss 0.00000521
# | Epoch  53 |   250/  401 batches | lr 0.00010 | ms/batch  6.56 | loss 0.00000723
# | Epoch  53 |   275/  401 batches | lr 0.00010 | ms/batch  7.13 | loss 0.00000448
# | Epoch  53 |   300/  401 batches | lr 0.00010 | ms/batch  5.68 | loss 0.00000644
# | Epoch  53 |   325/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00001492
# | Epoch  53 |   350/  401 batches | lr 0.00010 | ms/batch  6.94 | loss 0.00001088
# | Epoch  53 |   375/  401 batches | lr 0.00010 | ms/batch  5.21 | loss 0.00000653
# | Epoch  54 |    25/  401 batches | lr 0.00010 | ms/batch  6.98 | loss 0.00001120
# | Epoch  54 |    50/  401 batches | lr 0.00010 | ms/batch  5.72 | loss 0.00001305
# | Epoch  54 |    75/  401 batches | lr 0.00010 | ms/batch  6.73 | loss 0.00000654
# | Epoch  54 |   100/  401 batches | lr 0.00010 | ms/batch  7.03 | loss 0.00000414
# | Epoch  54 |   125/  401 batches | lr 0.00010 | ms/batch  5.52 | loss 0.00001450
# | Epoch  54 |   150/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00000440
# | Epoch  54 |   175/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00001011
# | Epoch  54 |   200/  401 batches | lr 0.00010 | ms/batch  5.53 | loss 0.00001922
# | Epoch  54 |   225/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00001357
# | Epoch  54 |   250/  401 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00000469
# | Epoch  54 |   275/  401 batches | lr 0.00010 | ms/batch  5.66 | loss 0.00000433
# | Epoch  54 |   300/  401 batches | lr 0.00010 | ms/batch  6.46 | loss 0.00000363
# | Epoch  54 |   325/  401 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00003060
# | Epoch  54 |   350/  401 batches | lr 0.00010 | ms/batch  5.64 | loss 0.00002289
# | Epoch  54 |   375/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000491
# | Epoch  55 |    25/  401 batches | lr 0.00010 | ms/batch  5.62 | loss 0.00000412
# | Epoch  55 |    50/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000300
# | Epoch  55 |    75/  401 batches | lr 0.00010 | ms/batch  6.44 | loss 0.00000361
# | Epoch  55 |   100/  401 batches | lr 0.00010 | ms/batch  5.42 | loss 0.00000351
# | Epoch  55 |   125/  401 batches | lr 0.00010 | ms/batch  6.72 | loss 0.00003704
# | Epoch  55 |   150/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00001387
# | Epoch  55 |   175/  401 batches | lr 0.00010 | ms/batch  5.87 | loss 0.00000694
# | Epoch  55 |   200/  401 batches | lr 0.00010 | ms/batch  6.52 | loss 0.00000719
# | Epoch  55 |   225/  401 batches | lr 0.00010 | ms/batch  6.40 | loss 0.00000382
# | Epoch  55 |   250/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00000363
# | Epoch  55 |   275/  401 batches | lr 0.00010 | ms/batch  6.87 | loss 0.00000429
# | Epoch  55 |   300/  401 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00000455
# | Epoch  55 |   325/  401 batches | lr 0.00010 | ms/batch  5.37 | loss 0.00002617
# | Epoch  55 |   350/  401 batches | lr 0.00010 | ms/batch  6.71 | loss 0.00002359
# | Epoch  55 |   375/  401 batches | lr 0.00010 | ms/batch  6.45 | loss 0.00000987
# | Epoch  56 |    25/  401 batches | lr 0.00010 | ms/batch  6.71 | loss 0.00000384
# | Epoch  56 |    50/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000301
# | Epoch  56 |    75/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000379
# | Epoch  56 |   100/  401 batches | lr 0.00010 | ms/batch  6.71 | loss 0.00000432
# | Epoch  56 |   125/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00000417
# | Epoch  56 |   150/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00002945
# | Epoch  56 |   175/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000665
# | Epoch  56 |   200/  401 batches | lr 0.00010 | ms/batch  6.88 | loss 0.00000362
# | Epoch  56 |   225/  401 batches | lr 0.00010 | ms/batch  6.64 | loss 0.00000922
# | Epoch  56 |   250/  401 batches | lr 0.00010 | ms/batch  5.57 | loss 0.00000423
# | Epoch  56 |   275/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000434
# | Epoch  56 |   300/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00001911
# | Epoch  56 |   325/  401 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00000801
# | Epoch  56 |   350/  401 batches | lr 0.00010 | ms/batch  6.91 | loss 0.00000683
# | Epoch  56 |   375/  401 batches | lr 0.00010 | ms/batch  5.36 | loss 0.00000511
# | Epoch  57 |    25/  401 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00002806
# | Epoch  57 |    50/  401 batches | lr 0.00010 | ms/batch  5.19 | loss 0.00000964
# | Epoch  57 |    75/  401 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00000538
# | Epoch  57 |   100/  401 batches | lr 0.00010 | ms/batch  6.65 | loss 0.00000542
# | Epoch  57 |   125/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000313
# | Epoch  57 |   150/  401 batches | lr 0.00010 | ms/batch  6.93 | loss 0.00000790
# | Epoch  57 |   175/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00000379
# | Epoch  57 |   200/  401 batches | lr 0.00010 | ms/batch  5.74 | loss 0.00003997
# | Epoch  57 |   225/  401 batches | lr 0.00010 | ms/batch  6.39 | loss 0.00001391
# | Epoch  57 |   250/  401 batches | lr 0.00010 | ms/batch  6.87 | loss 0.00000778
# | Epoch  57 |   275/  401 batches | lr 0.00010 | ms/batch  5.72 | loss 0.00000553
# | Epoch  57 |   300/  401 batches | lr 0.00010 | ms/batch  6.55 | loss 0.00000468
# | Epoch  57 |   325/  401 batches | lr 0.00010 | ms/batch  6.76 | loss 0.00001253
# | Epoch  57 |   350/  401 batches | lr 0.00010 | ms/batch  5.60 | loss 0.00000735
# | Epoch  57 |   375/  401 batches | lr 0.00010 | ms/batch  6.31 | loss 0.00000544
# | Epoch  58 |    25/  401 batches | lr 0.00010 | ms/batch  5.84 | loss 0.00000534
# | Epoch  58 |    50/  401 batches | lr 0.00010 | ms/batch  6.58 | loss 0.00000301
# | Epoch  58 |    75/  401 batches | lr 0.00010 | ms/batch  6.46 | loss 0.00000652
# | Epoch  58 |   100/  401 batches | lr 0.00010 | ms/batch  5.88 | loss 0.00000786
# | Epoch  58 |   125/  401 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00002100
# | Epoch  58 |   150/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00000577
# | Epoch  58 |   175/  401 batches | lr 0.00010 | ms/batch  5.44 | loss 0.00000502
# | Epoch  58 |   200/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000988
# | Epoch  58 |   225/  401 batches | lr 0.00010 | ms/batch  7.03 | loss 0.00001612
# | Epoch  58 |   250/  401 batches | lr 0.00010 | ms/batch  5.68 | loss 0.00000949
# | Epoch  58 |   275/  401 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00000477
# | Epoch  58 |   300/  401 batches | lr 0.00010 | ms/batch  6.86 | loss 0.00000591
# | Epoch  58 |   325/  401 batches | lr 0.00010 | ms/batch  5.35 | loss 0.00000671
# | Epoch  58 |   350/  401 batches | lr 0.00010 | ms/batch  7.49 | loss 0.00000409
# | Epoch  58 |   375/  401 batches | lr 0.00010 | ms/batch  6.72 | loss 0.00003025
# | Epoch  59 |    25/  401 batches | lr 0.00010 | ms/batch  7.00 | loss 0.00000467
# | Epoch  59 |    50/  401 batches | lr 0.00010 | ms/batch  7.10 | loss 0.00000262
# | Epoch  59 |    75/  401 batches | lr 0.00010 | ms/batch  5.87 | loss 0.00000439
# | Epoch  59 |   100/  401 batches | lr 0.00010 | ms/batch  6.95 | loss 0.00001164
# | Epoch  59 |   125/  401 batches | lr 0.00010 | ms/batch  6.58 | loss 0.00001171
# | Epoch  59 |   150/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000468
# | Epoch  59 |   175/  401 batches | lr 0.00010 | ms/batch  7.42 | loss 0.00000475
# | Epoch  59 |   200/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00002410
# | Epoch  59 |   225/  401 batches | lr 0.00010 | ms/batch  5.70 | loss 0.00000899
# | Epoch  59 |   250/  401 batches | lr 0.00010 | ms/batch  6.88 | loss 0.00000966
# | Epoch  59 |   275/  401 batches | lr 0.00010 | ms/batch  6.49 | loss 0.00000340
# | Epoch  59 |   300/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000522
# | Epoch  59 |   325/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000690
# | Epoch  59 |   350/  401 batches | lr 0.00010 | ms/batch  6.87 | loss 0.00000471
# | Epoch  59 |   375/  401 batches | lr 0.00010 | ms/batch  5.57 | loss 0.00001658
# | Epoch  60 |    25/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000568
# | Epoch  60 |    50/  401 batches | lr 0.00010 | ms/batch  5.57 | loss 0.00001920
# | Epoch  60 |    75/  401 batches | lr 0.00010 | ms/batch  7.16 | loss 0.00000788
# | Epoch  60 |   100/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00000334
# | Epoch  60 |   125/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00000792
# | Epoch  60 |   150/  401 batches | lr 0.00010 | ms/batch  7.19 | loss 0.00000780
# | Epoch  60 |   175/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000705
# | Epoch  60 |   200/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00002338
# | Epoch  60 |   225/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00002236
# | Epoch  60 |   250/  401 batches | lr 0.00010 | ms/batch  7.19 | loss 0.00000871
# | Epoch  60 |   275/  401 batches | lr 0.00010 | ms/batch  5.65 | loss 0.00000469
# | Epoch  60 |   300/  401 batches | lr 0.00010 | ms/batch  6.56 | loss 0.00000451
# | Epoch  60 |   325/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00001171
# | Epoch  60 |   350/  401 batches | lr 0.00010 | ms/batch  5.71 | loss 0.00000638
# | Epoch  60 |   375/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000497
# | Epoch  61 |    25/  401 batches | lr 0.00010 | ms/batch  5.39 | loss 0.00000424
# | Epoch  61 |    50/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000738
# | Epoch  61 |    75/  401 batches | lr 0.00010 | ms/batch  6.64 | loss 0.00000396
# | Epoch  61 |   100/  401 batches | lr 0.00010 | ms/batch  5.31 | loss 0.00000439
# | Epoch  61 |   125/  401 batches | lr 0.00010 | ms/batch  6.48 | loss 0.00004320
# | Epoch  61 |   150/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00001053
# | Epoch  61 |   175/  401 batches | lr 0.00010 | ms/batch  5.53 | loss 0.00000534
# | Epoch  61 |   200/  401 batches | lr 0.00010 | ms/batch  6.76 | loss 0.00000519
# | Epoch  61 |   225/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000483
# | Epoch  61 |   250/  401 batches | lr 0.00010 | ms/batch  5.68 | loss 0.00000445
# | Epoch  61 |   275/  401 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00000264
# | Epoch  61 |   300/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000288
# | Epoch  61 |   325/  401 batches | lr 0.00010 | ms/batch  5.71 | loss 0.00000729
# | Epoch  61 |   350/  401 batches | lr 0.00010 | ms/batch  6.73 | loss 0.00001703
# | Epoch  61 |   375/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00000371
# | Epoch  62 |    25/  401 batches | lr 0.00010 | ms/batch  5.59 | loss 0.00000604
# | Epoch  62 |    50/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00001034
# | Epoch  62 |    75/  401 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00000471
# | Epoch  62 |   100/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00001398
# | Epoch  62 |   125/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00002701
# | Epoch  62 |   150/  401 batches | lr 0.00010 | ms/batch  6.56 | loss 0.00000775
# | Epoch  62 |   175/  401 batches | lr 0.00010 | ms/batch  6.10 | loss 0.00000467
# | Epoch  62 |   200/  401 batches | lr 0.00010 | ms/batch  9.90 | loss 0.00000329
# | Epoch  62 |   225/  401 batches | lr 0.00010 | ms/batch  6.96 | loss 0.00000311
# | Epoch  62 |   250/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000575
# | Epoch  62 |   275/  401 batches | lr 0.00010 | ms/batch  6.64 | loss 0.00001092
# | Epoch  62 |   300/  401 batches | lr 0.00010 | ms/batch  7.21 | loss 0.00000351
# | Epoch  62 |   325/  401 batches | lr 0.00010 | ms/batch  5.60 | loss 0.00001801
# | Epoch  62 |   350/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00001534
# | Epoch  62 |   375/  401 batches | lr 0.00010 | ms/batch  6.58 | loss 0.00000579
# | Epoch  63 |    25/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00000618
# | Epoch  63 |    50/  401 batches | lr 0.00010 | ms/batch  6.43 | loss 0.00000652
# | Epoch  63 |    75/  401 batches | lr 0.00010 | ms/batch  5.59 | loss 0.00000362
# | Epoch  63 |   100/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000381
# | Epoch  63 |   125/  401 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00006280
# | Epoch  63 |   150/  401 batches | lr 0.00010 | ms/batch  5.84 | loss 0.00001711
# | Epoch  63 |   175/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000586
# | Epoch  63 |   200/  401 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00000298
# | Epoch  63 |   225/  401 batches | lr 0.00010 | ms/batch  5.64 | loss 0.00000275
# | Epoch  63 |   250/  401 batches | lr 0.00010 | ms/batch  6.58 | loss 0.00000267
# | Epoch  63 |   275/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000315
# | Epoch  63 |   300/  401 batches | lr 0.00010 | ms/batch  5.69 | loss 0.00000358
# | Epoch  63 |   325/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00001148
# | Epoch  63 |   350/  401 batches | lr 0.00010 | ms/batch  6.66 | loss 0.00000662
# | Epoch  63 |   375/  401 batches | lr 0.00010 | ms/batch  5.75 | loss 0.00000356
# | Epoch  64 |    25/  401 batches | lr 0.00010 | ms/batch  6.55 | loss 0.00000390
# | Epoch  64 |    50/  401 batches | lr 0.00010 | ms/batch  5.61 | loss 0.00000377
# | Epoch  64 |    75/  401 batches | lr 0.00010 | ms/batch  7.21 | loss 0.00000352
# | Epoch  64 |   100/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00002967
# | Epoch  64 |   125/  401 batches | lr 0.00010 | ms/batch  5.63 | loss 0.00001026
# | Epoch  64 |   150/  401 batches | lr 0.00010 | ms/batch  7.07 | loss 0.00000335
# | Epoch  64 |   175/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00000391
# | Epoch  64 |   200/  401 batches | lr 0.00010 | ms/batch  5.93 | loss 0.00000247
# | Epoch  64 |   225/  401 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00000529
# | Epoch  64 |   250/  401 batches | lr 0.00010 | ms/batch  6.98 | loss 0.00001776
# | Epoch  64 |   275/  401 batches | lr 0.00010 | ms/batch  5.44 | loss 0.00003444
# | Epoch  64 |   300/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00000669
# | Epoch  64 |   325/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00001118
# | Epoch  64 |   350/  401 batches | lr 0.00010 | ms/batch  5.59 | loss 0.00000464
# | Epoch  64 |   375/  401 batches | lr 0.00010 | ms/batch  6.82 | loss 0.00000310
# | Epoch  65 |    25/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00000516
# | Epoch  65 |    50/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00000267
# | Epoch  65 |    75/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000250
# | Epoch  65 |   100/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00000500
# | Epoch  65 |   125/  401 batches | lr 0.00010 | ms/batch  7.35 | loss 0.00000706
# | Epoch  65 |   150/  401 batches | lr 0.00010 | ms/batch  6.63 | loss 0.00000599
# | Epoch  65 |   175/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00001715
# | Epoch  65 |   200/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00001784
# | Epoch  65 |   225/  401 batches | lr 0.00010 | ms/batch  7.13 | loss 0.00000595
# | Epoch  65 |   250/  401 batches | lr 0.00010 | ms/batch  5.53 | loss 0.00000350
# | Epoch  65 |   275/  401 batches | lr 0.00010 | ms/batch  6.86 | loss 0.00000595
# | Epoch  65 |   300/  401 batches | lr 0.00010 | ms/batch  7.00 | loss 0.00000275
# | Epoch  65 |   325/  401 batches | lr 0.00010 | ms/batch  6.65 | loss 0.00000335
# | Epoch  65 |   350/  401 batches | lr 0.00010 | ms/batch  5.33 | loss 0.00003252
# | Epoch  65 |   375/  401 batches | lr 0.00010 | ms/batch  7.23 | loss 0.00001515
# | Epoch  66 |    25/  401 batches | lr 0.00010 | ms/batch  5.84 | loss 0.00000481
# | Epoch  66 |    50/  401 batches | lr 0.00010 | ms/batch  7.12 | loss 0.00000234
# | Epoch  66 |    75/  401 batches | lr 0.00010 | ms/batch  7.13 | loss 0.00000435
# | Epoch  66 |   100/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000592
# | Epoch  66 |   125/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00000545
# | Epoch  66 |   150/  401 batches | lr 0.00010 | ms/batch  6.55 | loss 0.00000261
# | Epoch  66 |   175/  401 batches | lr 0.00010 | ms/batch  5.65 | loss 0.00000345
# | Epoch  66 |   200/  401 batches | lr 0.00010 | ms/batch  7.01 | loss 0.00003463
# | Epoch  66 |   225/  401 batches | lr 0.00010 | ms/batch  6.87 | loss 0.00001401
# | Epoch  66 |   250/  401 batches | lr 0.00010 | ms/batch  5.66 | loss 0.00000601
# | Epoch  66 |   275/  401 batches | lr 0.00010 | ms/batch  7.24 | loss 0.00000345
# | Epoch  66 |   300/  401 batches | lr 0.00010 | ms/batch  6.87 | loss 0.00000406
# | Epoch  66 |   325/  401 batches | lr 0.00010 | ms/batch  5.68 | loss 0.00001098
# | Epoch  66 |   350/  401 batches | lr 0.00010 | ms/batch  7.24 | loss 0.00000534
# | Epoch  66 |   375/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00000507
# | Epoch  67 |    25/  401 batches | lr 0.00010 | ms/batch  7.11 | loss 0.00000246
# | Epoch  67 |    50/  401 batches | lr 0.00010 | ms/batch  6.77 | loss 0.00000213
# | Epoch  67 |    75/  401 batches | lr 0.00010 | ms/batch  5.69 | loss 0.00002530
# | Epoch  67 |   100/  401 batches | lr 0.00010 | ms/batch  6.98 | loss 0.00000989
# | Epoch  67 |   125/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000303
# | Epoch  67 |   150/  401 batches | lr 0.00010 | ms/batch  5.41 | loss 0.00000263
# | Epoch  67 |   175/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00000428
# | Epoch  67 |   200/  401 batches | lr 0.00010 | ms/batch  5.72 | loss 0.00001582
# | Epoch  67 |   225/  401 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00001457
# | Epoch  67 |   250/  401 batches | lr 0.00010 | ms/batch  7.02 | loss 0.00000622
# | Epoch  67 |   275/  401 batches | lr 0.00010 | ms/batch  7.18 | loss 0.00000385
# | Epoch  67 |   300/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000397
# | Epoch  67 |   325/  401 batches | lr 0.00010 | ms/batch  6.74 | loss 0.00000667
# | Epoch  67 |   350/  401 batches | lr 0.00010 | ms/batch  6.97 | loss 0.00000613
# | Epoch  67 |   375/  401 batches | lr 0.00010 | ms/batch  5.67 | loss 0.00001373
# | Epoch  68 |    25/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000330
# | Epoch  68 |    50/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00001268
# | Epoch  68 |    75/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00000561
# | Epoch  68 |   100/  401 batches | lr 0.00010 | ms/batch  7.12 | loss 0.00000792
# | Epoch  68 |   125/  401 batches | lr 0.00010 | ms/batch  5.57 | loss 0.00000932
# | Epoch  68 |   150/  401 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00000266
# | Epoch  68 |   175/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00002351
# | Epoch  68 |   200/  401 batches | lr 0.00010 | ms/batch  7.06 | loss 0.00001513
# | Epoch  68 |   225/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00001252
# | Epoch  68 |   250/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00000645
# | Epoch  68 |   275/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000537
# | Epoch  68 |   300/  401 batches | lr 0.00010 | ms/batch  5.48 | loss 0.00000463
# | Epoch  68 |   325/  401 batches | lr 0.00010 | ms/batch  7.13 | loss 0.00001006
# | Epoch  68 |   350/  401 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00000508
# | Epoch  68 |   375/  401 batches | lr 0.00010 | ms/batch  5.57 | loss 0.00000469
# | Epoch  69 |    25/  401 batches | lr 0.00010 | ms/batch  6.90 | loss 0.00000406
# | Epoch  69 |    50/  401 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00000560
# | Epoch  69 |    75/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00000966
# | Epoch  69 |   100/  401 batches | lr 0.00010 | ms/batch  7.32 | loss 0.00001544
# | Epoch  69 |   125/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00000697
# | Epoch  69 |   150/  401 batches | lr 0.00010 | ms/batch  5.52 | loss 0.00000417
# | Epoch  69 |   175/  401 batches | lr 0.00010 | ms/batch  7.17 | loss 0.00000279
# | Epoch  69 |   200/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00001493
# | Epoch  69 |   225/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00001729
# | Epoch  69 |   250/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00000828
# | Epoch  69 |   275/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000364
# | Epoch  69 |   300/  401 batches | lr 0.00010 | ms/batch  5.70 | loss 0.00000434
# | Epoch  69 |   325/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00000434
# | Epoch  69 |   350/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00000564
# | Epoch  69 |   375/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00000351
# | Epoch  70 |    25/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00001908
# | Epoch  70 |    50/  401 batches | lr 0.00010 | ms/batch  5.60 | loss 0.00000650
# | Epoch  70 |    75/  401 batches | lr 0.00010 | ms/batch  7.18 | loss 0.00000421
# | Epoch  70 |   100/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00000460
# | Epoch  70 |   125/  401 batches | lr 0.00010 | ms/batch  5.64 | loss 0.00000266
# | Epoch  70 |   150/  401 batches | lr 0.00010 | ms/batch  7.12 | loss 0.00000234
# | Epoch  70 |   175/  401 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00002259
# | Epoch  70 |   200/  401 batches | lr 0.00010 | ms/batch  5.69 | loss 0.00001794
# | Epoch  70 |   225/  401 batches | lr 0.00010 | ms/batch  6.96 | loss 0.00001286
# | Epoch  70 |   250/  401 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00000779
# | Epoch  70 |   275/  401 batches | lr 0.00010 | ms/batch  5.46 | loss 0.00000277
# | Epoch  70 |   300/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00000375
# | Epoch  70 |   325/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00001075
# | Epoch  70 |   350/  401 batches | lr 0.00010 | ms/batch  5.44 | loss 0.00000669
# | Epoch  70 |   375/  401 batches | lr 0.00010 | ms/batch  6.97 | loss 0.00000519
# | Epoch  71 |    25/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000488
# | Epoch  71 |    50/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00000224
# | Epoch  71 |    75/  401 batches | lr 0.00010 | ms/batch  6.95 | loss 0.00000385
# | Epoch  71 |   100/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00000805
# | Epoch  71 |   125/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00001387
# | Epoch  71 |   150/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00000397
# | Epoch  71 |   175/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000775
# | Epoch  71 |   200/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000929
# | Epoch  71 |   225/  401 batches | lr 0.00010 | ms/batch  6.91 | loss 0.00002583
# | Epoch  71 |   250/  401 batches | lr 0.00010 | ms/batch  6.96 | loss 0.00001088
# | Epoch  71 |   275/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00000420
# | Epoch  71 |   300/  401 batches | lr 0.00010 | ms/batch  6.93 | loss 0.00000449
# | Epoch  71 |   325/  401 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00001024
# | Epoch  71 |   350/  401 batches | lr 0.00010 | ms/batch  5.95 | loss 0.00000792
# | Epoch  71 |   375/  401 batches | lr 0.00010 | ms/batch  7.10 | loss 0.00000520
# | Epoch  72 |    25/  401 batches | lr 0.00010 | ms/batch  5.53 | loss 0.00000592
# | Epoch  72 |    50/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000252
# | Epoch  72 |    75/  401 batches | lr 0.00010 | ms/batch  6.93 | loss 0.00000228
# | Epoch  72 |   100/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00001450
# | Epoch  72 |   125/  401 batches | lr 0.00010 | ms/batch  7.04 | loss 0.00000810
# | Epoch  72 |   150/  401 batches | lr 0.00010 | ms/batch  7.30 | loss 0.00000322
# | Epoch  72 |   175/  401 batches | lr 0.00010 | ms/batch  5.63 | loss 0.00000262
# | Epoch  72 |   200/  401 batches | lr 0.00010 | ms/batch  6.96 | loss 0.00001555
# | Epoch  72 |   225/  401 batches | lr 0.00010 | ms/batch  7.08 | loss 0.00001686
# | Epoch  72 |   250/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00000774
# | Epoch  72 |   275/  401 batches | lr 0.00010 | ms/batch  5.55 | loss 0.00000315
# | Epoch  72 |   300/  401 batches | lr 0.00010 | ms/batch  6.58 | loss 0.00000372
# | Epoch  72 |   325/  401 batches | lr 0.00010 | ms/batch  7.01 | loss 0.00000489
# | Epoch  72 |   350/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000521
# | Epoch  72 |   375/  401 batches | lr 0.00010 | ms/batch  7.31 | loss 0.00000473
# | Epoch  73 |    25/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000612
# | Epoch  73 |    50/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00000686
# | Epoch  73 |    75/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00001420
# | Epoch  73 |   100/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00000777
# | Epoch  73 |   125/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000576
# | Epoch  73 |   150/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00000453
# | Epoch  73 |   175/  401 batches | lr 0.00010 | ms/batch  5.70 | loss 0.00000345
# | Epoch  73 |   200/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00002666
# | Epoch  73 |   225/  401 batches | lr 0.00010 | ms/batch  6.72 | loss 0.00000924
# | Epoch  73 |   250/  401 batches | lr 0.00010 | ms/batch  5.38 | loss 0.00000292
# | Epoch  73 |   275/  401 batches | lr 0.00010 | ms/batch  6.66 | loss 0.00000312
# | Epoch  73 |   300/  401 batches | lr 0.00010 | ms/batch  6.94 | loss 0.00000307
# | Epoch  73 |   325/  401 batches | lr 0.00010 | ms/batch  5.35 | loss 0.00000691
# | Epoch  73 |   350/  401 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00000623
# | Epoch  73 |   375/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00001162
# | Epoch  74 |    25/  401 batches | lr 0.00010 | ms/batch  6.82 | loss 0.00000479
# | Epoch  74 |    50/  401 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00000926
# | Epoch  74 |    75/  401 batches | lr 0.00010 | ms/batch  6.82 | loss 0.00000732
# | Epoch  74 |   100/  401 batches | lr 0.00010 | ms/batch  5.68 | loss 0.00000910
# | Epoch  74 |   125/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00000503
# | Epoch  74 |   150/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00000359
# | Epoch  74 |   175/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000381
# | Epoch  74 |   200/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00003160
# | Epoch  74 |   225/  401 batches | lr 0.00010 | ms/batch  6.63 | loss 0.00000507
# | Epoch  74 |   250/  401 batches | lr 0.00010 | ms/batch  5.47 | loss 0.00000317
# | Epoch  74 |   275/  401 batches | lr 0.00010 | ms/batch  6.56 | loss 0.00000318
# | Epoch  74 |   300/  401 batches | lr 0.00010 | ms/batch  7.32 | loss 0.00000383
# | Epoch  74 |   325/  401 batches | lr 0.00010 | ms/batch  5.67 | loss 0.00000436
# | Epoch  74 |   350/  401 batches | lr 0.00010 | ms/batch  6.88 | loss 0.00000760
# | Epoch  74 |   375/  401 batches | lr 0.00010 | ms/batch  6.87 | loss 0.00001015
# | Epoch  75 |    25/  401 batches | lr 0.00010 | ms/batch  6.82 | loss 0.00000467
# | Epoch  75 |    50/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00000398
# | Epoch  75 |    75/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00002160
# | Epoch  75 |   100/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00000742
# | Epoch  75 |   125/  401 batches | lr 0.00010 | ms/batch  6.76 | loss 0.00000316
# | Epoch  75 |   150/  401 batches | lr 0.00010 | ms/batch  5.40 | loss 0.00000270
# | Epoch  75 |   175/  401 batches | lr 0.00010 | ms/batch  6.82 | loss 0.00000407
# | Epoch  75 |   200/  401 batches | lr 0.00010 | ms/batch  7.01 | loss 0.00001629
# | Epoch  75 |   225/  401 batches | lr 0.00010 | ms/batch  6.64 | loss 0.00001292
# | Epoch  75 |   250/  401 batches | lr 0.00010 | ms/batch  5.62 | loss 0.00000537
# | Epoch  75 |   275/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00000211
# | Epoch  75 |   300/  401 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00000394
# | Epoch  75 |   325/  401 batches | lr 0.00010 | ms/batch  5.65 | loss 0.00000651
# | Epoch  75 |   350/  401 batches | lr 0.00010 | ms/batch  6.76 | loss 0.00000793
# | Epoch  75 |   375/  401 batches | lr 0.00010 | ms/batch  6.85 | loss 0.00001917
# | Epoch  76 |    25/  401 batches | lr 0.00010 | ms/batch  6.85 | loss 0.00000383
# | Epoch  76 |    50/  401 batches | lr 0.00010 | ms/batch  6.90 | loss 0.00000241
# | Epoch  76 |    75/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000584
# | Epoch  76 |   100/  401 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00001236
# | Epoch  76 |   125/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000403
# | Epoch  76 |   150/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00000329
# | Epoch  76 |   175/  401 batches | lr 0.00010 | ms/batch  7.22 | loss 0.00000330
# | Epoch  76 |   200/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00003148
# | Epoch  76 |   225/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00001064
# | Epoch  76 |   250/  401 batches | lr 0.00010 | ms/batch  7.35 | loss 0.00000613
# | Epoch  76 |   275/  401 batches | lr 0.00010 | ms/batch  7.02 | loss 0.00000487
# | Epoch  76 |   300/  401 batches | lr 0.00010 | ms/batch  5.75 | loss 0.00000465
# | Epoch  76 |   325/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00001087
# | Epoch  76 |   350/  401 batches | lr 0.00010 | ms/batch  6.86 | loss 0.00000671
# | Epoch  76 |   375/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00000612
# | Epoch  77 |    25/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00000474
# | Epoch  77 |    50/  401 batches | lr 0.00010 | ms/batch  5.54 | loss 0.00000223
# | Epoch  77 |    75/  401 batches | lr 0.00010 | ms/batch  6.73 | loss 0.00000210
# | Epoch  77 |   100/  401 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00001657
# | Epoch  77 |   125/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000541
# | Epoch  77 |   150/  401 batches | lr 0.00010 | ms/batch  5.68 | loss 0.00000323
# | Epoch  77 |   175/  401 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00000589
# | Epoch  77 |   200/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00000841
# | Epoch  77 |   225/  401 batches | lr 0.00010 | ms/batch  5.50 | loss 0.00001033
# | Epoch  77 |   250/  401 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00000635
# | Epoch  77 |   275/  401 batches | lr 0.00010 | ms/batch  7.03 | loss 0.00000262
# | Epoch  77 |   300/  401 batches | lr 0.00010 | ms/batch  5.67 | loss 0.00000563
# | Epoch  77 |   325/  401 batches | lr 0.00010 | ms/batch  6.76 | loss 0.00000964
# | Epoch  77 |   350/  401 batches | lr 0.00010 | ms/batch  6.86 | loss 0.00001128
# | Epoch  77 |   375/  401 batches | lr 0.00010 | ms/batch  5.59 | loss 0.00001422
# | Epoch  78 |    25/  401 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00000438
# | Epoch  78 |    50/  401 batches | lr 0.00010 | ms/batch  5.63 | loss 0.00000230
# | Epoch  78 |    75/  401 batches | lr 0.00010 | ms/batch  6.86 | loss 0.00000244
# | Epoch  78 |   100/  401 batches | lr 0.00010 | ms/batch  7.18 | loss 0.00000406
# | Epoch  78 |   125/  401 batches | lr 0.00010 | ms/batch  5.65 | loss 0.00002545
# | Epoch  78 |   150/  401 batches | lr 0.00010 | ms/batch  6.98 | loss 0.00000735
# | Epoch  78 |   175/  401 batches | lr 0.00010 | ms/batch  6.91 | loss 0.00000716
# | Epoch  78 |   200/  401 batches | lr 0.00010 | ms/batch  5.76 | loss 0.00000367
# | Epoch  78 |   225/  401 batches | lr 0.00010 | ms/batch  7.04 | loss 0.00000392
# | Epoch  78 |   250/  401 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00000379
# | Epoch  78 |   275/  401 batches | lr 0.00010 | ms/batch  7.17 | loss 0.00000352
# | Epoch  78 |   300/  401 batches | lr 0.00010 | ms/batch  5.43 | loss 0.00000330
# | Epoch  78 |   325/  401 batches | lr 0.00010 | ms/batch  6.73 | loss 0.00001525
# | Epoch  78 |   350/  401 batches | lr 0.00010 | ms/batch  5.47 | loss 0.00001094
# | Epoch  78 |   375/  401 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00001220
# | Epoch  79 |    25/  401 batches | lr 0.00010 | ms/batch  6.66 | loss 0.00000708
# | Epoch  79 |    50/  401 batches | lr 0.00010 | ms/batch  5.51 | loss 0.00000404
# | Epoch  79 |    75/  401 batches | lr 0.00010 | ms/batch  6.65 | loss 0.00000257
# | Epoch  79 |   100/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000532
# | Epoch  79 |   125/  401 batches | lr 0.00010 | ms/batch  5.57 | loss 0.00000601
# | Epoch  79 |   150/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00000249
# | Epoch  79 |   175/  401 batches | lr 0.00010 | ms/batch  7.06 | loss 0.00000247
# | Epoch  79 |   200/  401 batches | lr 0.00010 | ms/batch  5.49 | loss 0.00004263
# | Epoch  79 |   225/  401 batches | lr 0.00010 | ms/batch  6.54 | loss 0.00001674
# | Epoch  79 |   250/  401 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00000632
# | Epoch  79 |   275/  401 batches | lr 0.00010 | ms/batch  5.46 | loss 0.00000262
# | Epoch  79 |   300/  401 batches | lr 0.00010 | ms/batch  6.53 | loss 0.00000394
# | Epoch  79 |   325/  401 batches | lr 0.00010 | ms/batch  6.66 | loss 0.00001244
# | Epoch  79 |   350/  401 batches | lr 0.00010 | ms/batch  5.37 | loss 0.00000565
# | Epoch  79 |   375/  401 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00000378
# | Epoch  80 |    25/  401 batches | lr 0.00010 | ms/batch  5.56 | loss 0.00000351
# | Epoch  80 |    50/  401 batches | lr 0.00010 | ms/batch  6.57 | loss 0.00000251
# | Epoch  80 |    75/  401 batches | lr 0.00010 | ms/batch  6.51 | loss 0.00000252
# | Epoch  80 |   100/  401 batches | lr 0.00010 | ms/batch  5.78 | loss 0.00000240
# | Epoch  80 |   125/  401 batches | lr 0.00010 | ms/batch  6.80 | loss 0.00000865
# | Epoch  80 |   150/  401 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00000445
# | Epoch  80 |   175/  401 batches | lr 0.00010 | ms/batch  5.59 | loss 0.00000628
# | Epoch  80 |   200/  401 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00000963
# | Epoch  80 |   225/  401 batches | lr 0.00010 | ms/batch  6.40 | loss 0.00000941
# | Epoch  80 |   250/  401 batches | lr 0.00010 | ms/batch  5.66 | loss 0.00000403
# | Epoch  80 |   275/  401 batches | lr 0.00010 | ms/batch  6.66 | loss 0.00000267
# ...
# | Epoch 112 |    25/  401 batches | lr 0.00010 | ms/batch  8.44 | loss 0.00000207
# | Epoch 112 |    50/  401 batches | lr 0.00010 | ms/batch  8.12 | loss 0.00000148
# | Epoch 112 |    75/  401 batches | lr 0.00010 | ms/batch  7.65 | loss 0.00004552
# | Epoch 112 |   100/  401 batches | lr 0.00010 | ms/batch  8.87 | loss 0.00001844
# | Epoch 112 |   125/  401 batches | lr 0.00010 | ms/batch  8.87 | loss 0.00000272
# | Epoch 112 |   150/  401 batches | lr 0.00010 | ms/batch  7.15 | loss 0.00000133
# | Epoch 112 |   175/  401 batches | lr 0.00010 | ms/batch  8.35 | loss 0.00000189
# | Epoch 112 |   200/  401 batches | lr 0.00010 | ms/batch  8.62 | loss 0.00000230
# | Epoch 112 |   225/  401 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00001080
# | Epoch 112 |   250/  401 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00000744
# | Epoch 112 |   275/  401 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00000177
# | Epoch 112 |   300/  401 batches | lr 0.00010 | ms/batch  8.03 | loss 0.00000165
# | Epoch 112 |   325/  401 batches | lr 0.00010 | ms/batch  8.37 | loss 0.00000237
# | Epoch 112 |   350/  401 batches | lr 0.00010 | ms/batch  6.97 | loss 0.00000227
# | Epoch 112 |   375/  401 batches | lr 0.00010 | ms/batch  8.49 | loss 0.00000299
# | Epoch 113 |    25/  401 batches | lr 0.00010 | ms/batch  7.22 | loss 0.00000433
# | Epoch 113 |    50/  401 batches | lr 0.00010 | ms/batch  8.61 | loss 0.00000166
# | Epoch 113 |    75/  401 batches | lr 0.00010 | ms/batch  8.00 | loss 0.00000503
# | Epoch 113 |   100/  401 batches | lr 0.00010 | ms/batch  7.17 | loss 0.00000571
# | Epoch 113 |   125/  401 batches | lr 0.00010 | ms/batch  8.10 | loss 0.00000200
# | Epoch 113 |   150/  401 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00000143
# | Epoch 113 |   175/  401 batches | lr 0.00010 | ms/batch  7.25 | loss 0.00000214
# | Epoch 113 |   200/  401 batches | lr 0.00010 | ms/batch  8.18 | loss 0.00000480
# | Epoch 113 |   225/  401 batches | lr 0.00010 | ms/batch  8.51 | loss 0.00000856
# | Epoch 113 |   250/  401 batches | lr 0.00010 | ms/batch  6.88 | loss 0.00000370
# | Epoch 113 |   275/  401 batches | lr 0.00010 | ms/batch  8.02 | loss 0.00000293
# | Epoch 113 |   300/  401 batches | lr 0.00010 | ms/batch  8.29 | loss 0.00000847
# | Epoch 113 |   325/  401 batches | lr 0.00010 | ms/batch  6.89 | loss 0.00000287
# | Epoch 113 |   350/  401 batches | lr 0.00010 | ms/batch  8.16 | loss 0.00000368
# | Epoch 113 |   375/  401 batches | lr 0.00010 | ms/batch  7.17 | loss 0.00000878
# | Epoch 114 |    25/  401 batches | lr 0.00010 | ms/batch  8.91 | loss 0.00000308
# | Epoch 114 |    50/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00000532
# | Epoch 114 |    75/  401 batches | lr 0.00010 | ms/batch  8.18 | loss 0.00000383
# | Epoch 114 |   100/  401 batches | lr 0.00010 | ms/batch  8.34 | loss 0.00000240
# | Epoch 114 |   125/  401 batches | lr 0.00010 | ms/batch  7.07 | loss 0.00001226
# | Epoch 114 |   150/  401 batches | lr 0.00010 | ms/batch  8.58 | loss 0.00000260
# | Epoch 114 |   175/  401 batches | lr 0.00010 | ms/batch  8.71 | loss 0.00000215
# | Epoch 114 |   200/  401 batches | lr 0.00010 | ms/batch  7.37 | loss 0.00000934
# | Epoch 114 |   225/  401 batches | lr 0.00010 | ms/batch  8.37 | loss 0.00000734
# | Epoch 114 |   250/  401 batches | lr 0.00010 | ms/batch  8.02 | loss 0.00000319
# | Epoch 114 |   275/  401 batches | lr 0.00010 | ms/batch  7.57 | loss 0.00000402
# | Epoch 114 |   300/  401 batches | lr 0.00010 | ms/batch  8.02 | loss 0.00000596
# | Epoch 114 |   325/  401 batches | lr 0.00010 | ms/batch  8.00 | loss 0.00000372
# | Epoch 114 |   350/  401 batches | lr 0.00010 | ms/batch  7.23 | loss 0.00000508
# | Epoch 114 |   375/  401 batches | lr 0.00010 | ms/batch  8.10 | loss 0.00000913
# | Epoch 115 |    25/  401 batches | lr 0.00010 | ms/batch  7.24 | loss 0.00000212
# | Epoch 115 |    50/  401 batches | lr 0.00010 | ms/batch  8.67 | loss 0.00000336
# | Epoch 115 |    75/  401 batches | lr 0.00010 | ms/batch  8.27 | loss 0.00000714
# | Epoch 115 |   100/  401 batches | lr 0.00010 | ms/batch  7.01 | loss 0.00000624
# | Epoch 115 |   125/  401 batches | lr 0.00010 | ms/batch  8.37 | loss 0.00000350
# | Epoch 115 |   150/  401 batches | lr 0.00010 | ms/batch  7.15 | loss 0.00000199
# | Epoch 115 |   175/  401 batches | lr 0.00010 | ms/batch  8.53 | loss 0.00000231
# | Epoch 115 |   200/  401 batches | lr 0.00010 | ms/batch  8.58 | loss 0.00001282
# | Epoch 115 |   225/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00002746
# | Epoch 115 |   250/  401 batches | lr 0.00010 | ms/batch  8.75 | loss 0.00001227
# | Epoch 115 |   275/  401 batches | lr 0.00010 | ms/batch  8.07 | loss 0.00000293
# | Epoch 115 |   300/  401 batches | lr 0.00010 | ms/batch  7.14 | loss 0.00000210
# | Epoch 115 |   325/  401 batches | lr 0.00010 | ms/batch  8.63 | loss 0.00000243
# | Epoch 115 |   350/  401 batches | lr 0.00010 | ms/batch  8.48 | loss 0.00000223
# | Epoch 115 |   375/  401 batches | lr 0.00010 | ms/batch  7.34 | loss 0.00000232
# | Epoch 116 |    25/  401 batches | lr 0.00010 | ms/batch  8.34 | loss 0.00000402
# | Epoch 116 |    50/  401 batches | lr 0.00010 | ms/batch  7.07 | loss 0.00000223
# | Epoch 116 |    75/  401 batches | lr 0.00010 | ms/batch  8.39 | loss 0.00000237
# | Epoch 116 |   100/  401 batches | lr 0.00010 | ms/batch  8.40 | loss 0.00000605
# | Epoch 116 |   125/  401 batches | lr 0.00010 | ms/batch  6.94 | loss 0.00000181
# | Epoch 116 |   150/  401 batches | lr 0.00010 | ms/batch  8.24 | loss 0.00000210
# | Epoch 116 |   175/  401 batches | lr 0.00010 | ms/batch  8.40 | loss 0.00000233
# | Epoch 116 |   200/  401 batches | lr 0.00010 | ms/batch  7.04 | loss 0.00000602
# | Epoch 116 |   225/  401 batches | lr 0.00010 | ms/batch  8.41 | loss 0.00001524
# | Epoch 116 |   250/  401 batches | lr 0.00010 | ms/batch  8.25 | loss 0.00000344
# | Epoch 116 |   275/  401 batches | lr 0.00010 | ms/batch  7.13 | loss 0.00000268
# | Epoch 116 |   300/  401 batches | lr 0.00010 | ms/batch  8.49 | loss 0.00000173
# | Epoch 116 |   325/  401 batches | lr 0.00010 | ms/batch  7.03 | loss 0.00000158
# | Epoch 116 |   350/  401 batches | lr 0.00010 | ms/batch  8.03 | loss 0.00000322
# | Epoch 116 |   375/  401 batches | lr 0.00010 | ms/batch  8.46 | loss 0.00000543
# | Epoch 117 |    25/  401 batches | lr 0.00010 | ms/batch  8.42 | loss 0.00000769
# | Epoch 117 |    50/  401 batches | lr 0.00010 | ms/batch  8.46 | loss 0.00000458
# | Epoch 117 |    75/  401 batches | lr 0.00010 | ms/batch  7.29 | loss 0.00000229
# | Epoch 117 |   100/  401 batches | lr 0.00010 | ms/batch  8.91 | loss 0.00000291
# | Epoch 117 |   125/  401 batches | lr 0.00010 | ms/batch  8.46 | loss 0.00000402
# | Epoch 117 |   150/  401 batches | lr 0.00010 | ms/batch  7.29 | loss 0.00000630
# | Epoch 117 |   175/  401 batches | lr 0.00010 | ms/batch  8.61 | loss 0.00000298
# | Epoch 117 |   200/  401 batches | lr 0.00010 | ms/batch  8.68 | loss 0.00000871
# | Epoch 117 |   225/  401 batches | lr 0.00010 | ms/batch  7.60 | loss 0.00000951
# | Epoch 117 |   250/  401 batches | lr 0.00010 | ms/batch  8.35 | loss 0.00000366
# | Epoch 117 |   275/  401 batches | lr 0.00010 | ms/batch  8.62 | loss 0.00000192
# | Epoch 117 |   300/  401 batches | lr 0.00010 | ms/batch  7.00 | loss 0.00000160
# | Epoch 117 |   325/  401 batches | lr 0.00010 | ms/batch  8.26 | loss 0.00000178
# | Epoch 117 |   350/  401 batches | lr 0.00010 | ms/batch  8.46 | loss 0.00001443
# | Epoch 117 |   375/  401 batches | lr 0.00010 | ms/batch  7.18 | loss 0.00001730
# | Epoch 118 |    25/  401 batches | lr 0.00010 | ms/batch  8.38 | loss 0.00000375
# | Epoch 118 |    50/  401 batches | lr 0.00010 | ms/batch  6.97 | loss 0.00000327
# | Epoch 118 |    75/  401 batches | lr 0.00010 | ms/batch  8.75 | loss 0.00000222
# | Epoch 118 |   100/  401 batches | lr 0.00010 | ms/batch  7.39 | loss 0.00000791
# | Epoch 118 |   125/  401 batches | lr 0.00010 | ms/batch  8.21 | loss 0.00000465
# | Epoch 118 |   150/  401 batches | lr 0.00010 | ms/batch  8.17 | loss 0.00000334
# | Epoch 118 |   175/  401 batches | lr 0.00010 | ms/batch  7.21 | loss 0.00000241
# | Epoch 118 |   200/  401 batches | lr 0.00010 | ms/batch  8.52 | loss 0.00000939
# | Epoch 118 |   225/  401 batches | lr 0.00010 | ms/batch  8.22 | loss 0.00000543
# | Epoch 118 |   250/  401 batches | lr 0.00010 | ms/batch  7.26 | loss 0.00000374
# | Epoch 118 |   275/  401 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00000222
# | Epoch 118 |   300/  401 batches | lr 0.00010 | ms/batch  8.09 | loss 0.00000306
# | Epoch 118 |   325/  401 batches | lr 0.00010 | ms/batch  7.33 | loss 0.00000222
# | Epoch 118 |   350/  401 batches | lr 0.00010 | ms/batch  8.12 | loss 0.00000220
# | Epoch 118 |   375/  401 batches | lr 0.00010 | ms/batch  8.63 | loss 0.00002502
# | Epoch 119 |    25/  401 batches | lr 0.00010 | ms/batch  8.55 | loss 0.00000206
# | Epoch 119 |    50/  401 batches | lr 0.00010 | ms/batch  8.38 | loss 0.00000229
# | Epoch 119 |    75/  401 batches | lr 0.00010 | ms/batch  7.39 | loss 0.00000211
# | Epoch 119 |   100/  401 batches | lr 0.00010 | ms/batch  8.20 | loss 0.00000413
# | Epoch 119 |   125/  401 batches | lr 0.00010 | ms/batch  8.32 | loss 0.00000292
# | Epoch 119 |   150/  401 batches | lr 0.00010 | ms/batch  7.04 | loss 0.00000318
# | Epoch 119 |   175/  401 batches | lr 0.00010 | ms/batch  8.37 | loss 0.00000180
# | Epoch 119 |   200/  401 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00000650
# | Epoch 119 |   225/  401 batches | lr 0.00010 | ms/batch  7.29 | loss 0.00000310
# | Epoch 119 |   250/  401 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00000186
# | Epoch 119 |   275/  401 batches | lr 0.00010 | ms/batch  7.28 | loss 0.00000146
# | Epoch 119 |   300/  401 batches | lr 0.00010 | ms/batch  8.83 | loss 0.00000240
# | Epoch 119 |   325/  401 batches | lr 0.00010 | ms/batch  7.99 | loss 0.00002191
# | Epoch 119 |   350/  401 batches | lr 0.00010 | ms/batch  6.94 | loss 0.00001298
# | Epoch 119 |   375/  401 batches | lr 0.00010 | ms/batch  8.34 | loss 0.00000455
# | Epoch 120 |    25/  401 batches | lr 0.00010 | ms/batch  7.40 | loss 0.00000137
# | Epoch 120 |    50/  401 batches | lr 0.00010 | ms/batch  8.34 | loss 0.00000144
# | Epoch 120 |    75/  401 batches | lr 0.00010 | ms/batch  8.29 | loss 0.00000146
# | Epoch 120 |   100/  401 batches | lr 0.00010 | ms/batch  7.12 | loss 0.00000248
# | Epoch 120 |   125/  401 batches | lr 0.00010 | ms/batch  8.56 | loss 0.00000154
# | Epoch 120 |   150/  401 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00000174
# | Epoch 120 |   175/  401 batches | lr 0.00010 | ms/batch  7.07 | loss 0.00000208
# | Epoch 120 |   200/  401 batches | lr 0.00010 | ms/batch  8.28 | loss 0.00002540
# | Epoch 120 |   225/  401 batches | lr 0.00010 | ms/batch  8.27 | loss 0.00002962
# | Epoch 120 |   250/  401 batches | lr 0.00010 | ms/batch  7.02 | loss 0.00001815
# | Epoch 120 |   275/  401 batches | lr 0.00010 | ms/batch  8.47 | loss 0.00000385
# | Epoch 120 |   300/  401 batches | lr 0.00010 | ms/batch  8.25 | loss 0.00000239
# | Epoch 120 |   325/  401 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00000188
# | Epoch 120 |   350/  401 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00000216
# | Epoch 120 |   375/  401 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00000177
# | Epoch 121 |    25/  401 batches | lr 0.00010 | ms/batch  8.42 | loss 0.00000245
# | Epoch 121 |    50/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00000150
# | Epoch 121 |    75/  401 batches | lr 0.00010 | ms/batch  8.40 | loss 0.00000152
# | Epoch 121 |   100/  401 batches | lr 0.00010 | ms/batch  7.95 | loss 0.00000315
# | Epoch 121 |   125/  401 batches | lr 0.00010 | ms/batch  7.54 | loss 0.00000273
# | Epoch 121 |   150/  401 batches | lr 0.00010 | ms/batch  8.09 | loss 0.00000321
# | Epoch 121 |   175/  401 batches | lr 0.00010 | ms/batch  8.19 | loss 0.00000307
# | Epoch 121 |   200/  401 batches | lr 0.00010 | ms/batch  7.12 | loss 0.00000585
# | Epoch 121 |   225/  401 batches | lr 0.00010 | ms/batch  8.10 | loss 0.00001552
# | Epoch 121 |   250/  401 batches | lr 0.00010 | ms/batch  8.63 | loss 0.00000865
# | Epoch 121 |   275/  401 batches | lr 0.00010 | ms/batch  7.01 | loss 0.00000301
# | Epoch 121 |   300/  401 batches | lr 0.00010 | ms/batch  7.99 | loss 0.00000157
# | Epoch 121 |   325/  401 batches | lr 0.00010 | ms/batch  8.60 | loss 0.00000228
# | Epoch 121 |   350/  401 batches | lr 0.00010 | ms/batch  7.42 | loss 0.00000124
# | Epoch 121 |   375/  401 batches | lr 0.00010 | ms/batch  8.47 | loss 0.00000239
# | Epoch 122 |    25/  401 batches | lr 0.00010 | ms/batch  8.70 | loss 0.00000147
# | Epoch 122 |    50/  401 batches | lr 0.00010 | ms/batch  8.37 | loss 0.00000136
# | Epoch 122 |    75/  401 batches | lr 0.00010 | ms/batch  7.18 | loss 0.00000120
# | Epoch 122 |   100/  401 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00000300
# | Epoch 122 |   125/  401 batches | lr 0.00010 | ms/batch  8.14 | loss 0.00000977
# | Epoch 122 |   150/  401 batches | lr 0.00010 | ms/batch  7.08 | loss 0.00000249
# | Epoch 122 |   175/  401 batches | lr 0.00010 | ms/batch  8.70 | loss 0.00000133
# | Epoch 122 |   200/  401 batches | lr 0.00010 | ms/batch  7.92 | loss 0.00002183
# | Epoch 122 |   225/  401 batches | lr 0.00010 | ms/batch  7.24 | loss 0.00001479
# | Epoch 122 |   250/  401 batches | lr 0.00010 | ms/batch  8.42 | loss 0.00000839
# | Epoch 122 |   275/  401 batches | lr 0.00010 | ms/batch  8.11 | loss 0.00000247
# | Epoch 122 |   300/  401 batches | lr 0.00010 | ms/batch  7.48 | loss 0.00000195
# | Epoch 122 |   325/  401 batches | lr 0.00010 | ms/batch  8.24 | loss 0.00000227
# | Epoch 122 |   350/  401 batches | lr 0.00010 | ms/batch  8.23 | loss 0.00000150
# | Epoch 122 |   375/  401 batches | lr 0.00010 | ms/batch  7.36 | loss 0.00000230
# | Epoch 123 |    25/  401 batches | lr 0.00010 | ms/batch  8.31 | loss 0.00000235
# | Epoch 123 |    50/  401 batches | lr 0.00010 | ms/batch  7.21 | loss 0.00000177
# | Epoch 123 |    75/  401 batches | lr 0.00010 | ms/batch  8.57 | loss 0.00000188
# | Epoch 123 |   100/  401 batches | lr 0.00010 | ms/batch  7.28 | loss 0.00000329
# | Epoch 123 |   125/  401 batches | lr 0.00010 | ms/batch  8.37 | loss 0.00000909
# | Epoch 123 |   150/  401 batches | lr 0.00010 | ms/batch  8.39 | loss 0.00000506
# | Epoch 123 |   175/  401 batches | lr 0.00010 | ms/batch  7.09 | loss 0.00000191
# | Epoch 123 |   200/  401 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00001098
# | Epoch 123 |   225/  401 batches | lr 0.00010 | ms/batch  8.21 | loss 0.00000466
# | Epoch 123 |   250/  401 batches | lr 0.00010 | ms/batch  6.98 | loss 0.00000188
# | Epoch 123 |   275/  401 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00000145
# | Epoch 123 |   300/  401 batches | lr 0.00010 | ms/batch  8.22 | loss 0.00000196
# | Epoch 123 |   325/  401 batches | lr 0.00010 | ms/batch  7.05 | loss 0.00000293
# | Epoch 123 |   350/  401 batches | lr 0.00010 | ms/batch  8.43 | loss 0.00000601
# | Epoch 123 |   375/  401 batches | lr 0.00010 | ms/batch  8.48 | loss 0.00001212
# | Epoch 124 |    25/  401 batches | lr 0.00010 | ms/batch  8.29 | loss 0.00000527
# | Epoch 124 |    50/  401 batches | lr 0.00010 | ms/batch  8.15 | loss 0.00000261
# | Epoch 124 |    75/  401 batches | lr 0.00010 | ms/batch  7.28 | loss 0.00000287
# | Epoch 124 |   100/  401 batches | lr 0.00010 | ms/batch  8.17 | loss 0.00000208
# | Epoch 124 |   125/  401 batches | lr 0.00010 | ms/batch  8.53 | loss 0.00000296
# | Epoch 124 |   150/  401 batches | lr 0.00010 | ms/batch  7.19 | loss 0.00000358
# | Epoch 124 |   175/  401 batches | lr 0.00010 | ms/batch  8.06 | loss 0.00000566
# | Epoch 124 |   200/  401 batches | lr 0.00010 | ms/batch  7.40 | loss 0.00000739
# | Epoch 124 |   225/  401 batches | lr 0.00010 | ms/batch  8.45 | loss 0.00000930
# | Epoch 124 |   250/  401 batches | lr 0.00010 | ms/batch  8.20 | loss 0.00000210
# | Epoch 124 |   275/  401 batches | lr 0.00010 | ms/batch  7.42 | loss 0.00000203
# | Epoch 124 |   300/  401 batches | lr 0.00010 | ms/batch  8.29 | loss 0.00000146
# | Epoch 124 |   325/  401 batches | lr 0.00010 | ms/batch  8.46 | loss 0.00001309
# | Epoch 124 |   350/  401 batches | lr 0.00010 | ms/batch  7.32 | loss 0.00001072
# | Epoch 124 |   375/  401 batches | lr 0.00010 | ms/batch  8.01 | loss 0.00000540

# %%
testing_results
# Out:
#   hidden_size n_layers    act_fun    init_methods  mean_val_result  \
# 0         400        8  LeakyReLU  xavier uniform         0.000021
# 1         400        4       ReLU  xavier uniform         0.000020
# 2         400        4  LeakyReLU  xavier uniform         0.000022
# 3         400        6  LeakyReLU  xavier uniform         0.000020
# 4         400        8  LeakyReLU  xavier uniform         0.000016
#
#    std_val_result  test_mse  test_mae  test_rmse  test_mape
# 0        0.000034  0.000004  0.001650   0.002082  -0.001807
# 1        0.000037  0.000003  0.001316   0.001688  -0.014136
# 2        0.000039  0.000004  0.001653   0.002032  -0.001563
# 3        0.000033  0.000006  0.002011   0.002419  -0.001843
# 4        0.000024  0.000003  0.001375   0.001774   0.000067

# %%
testing_results.to_csv('../results/testing_results_binomial.csv')

# %% [markdown]
# Despite having lower `mean_val_result` and `std_val_result` the 4th model has quite worse results on than the 1st model both for the mse and mae metrics.
#
# Hence the choosen model is the the 1st:
#
# `{'n_hidden': 400, 'n_layers': 4, 'act_fun': 'ReLU', 'init_method': 'xavier uniform'}`
