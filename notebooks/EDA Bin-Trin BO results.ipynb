# %% [markdown]
# # EDA Bayesian Optimization Results for Binomial/Trinomial Dataset

# %%
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader

# %%
# Set seeds
torch.manual_seed(0)
np.random.seed(0)

# %%
res_path = '../results/bin-tri_bo_results.csv'

# %%
res_df = pd.read_csv(res_path, index_col=0)

# %%
res_df.sort_values('mean')
# Out:
#                 lr  batch_size  num_layers  hidden_size     act_fn  \
# arm_name
# 20_0      0.000062        1519           6          400  LeakyReLU
# 1_0       0.000026        2020           6          600  LeakyReLU
# 16_0      0.000037        1358           6          400  LeakyReLU
# 21_0      0.000032        1437           6          600  LeakyReLU
# 6_0       0.000058         755           8          400  LeakyReLU
# 18_0      0.001028        1384           6          400       ReLU
# 19_0      0.004058        1271           6          600       ReLU
# 14_0      0.000040        1394           8          600  LeakyReLU
# 8_0       0.010802        1014           6          400       ReLU
# 5_0       0.000184        1387           6          800        ELU
# 13_0      0.000064         984           8          400        ELU
# 17_0      0.000621        1322           8          400        ELU
# 9_0       0.000042        1582           8          800        ELU
# 4_0       0.006777        1186           4          400       ReLU
# 23_0      0.000140        2048           6          400        ELU
# 3_0       0.003015        1494           6          800       ReLU
# 11_0      0.000084        1336           8          600        ELU
# 12_0      0.003870        2048           4          800        ELU
# 15_0      0.005818        2048           4          400        ELU
# 32_0      0.001129        2039           6          600        ELU
# 24_0      0.011699        1088           4          600        ELU
# 36_0      0.013902        1447           4          600        ELU
# 2_0       0.000847         909           8          400        ELU
# 33_0      0.000777        1609           6          800        ELU
# 40_0      0.020407        1377           4          600        ELU
# 35_0      0.012570        1446           4          600        ELU
# 10_0      0.000841        1872           6          600        ELU
# 42_0      0.018321        1421           4          600        ELU
# 37_0      0.016816        1413           4          600        ELU
# 43_0      0.021190        1349           4          600        ELU
# 38_0      0.017628        1415           4          600        ELU
# 7_0       0.021173        1720           4          600        ELU
# 25_0      0.025095        1513           4          600        ELU
# 41_0      0.016131        1398           4          600        ELU
# 44_0      0.019985        1327           4          600        ELU
# 28_0      0.036915        1629           4          600        ELU
# 26_0      0.026483        1503           4          600        ELU
# 27_0      0.032605        1589           4          600        ELU
# 29_0      0.041271        1691           4          600        ELU
# 30_0      0.043032        1747           4          600        ELU
# 39_0      0.017801        1379           4          600        ELU
# 0_0       0.097736         672           4          600        ELU
# 34_0      0.100000        1736           4          600        ELU
# 22_0      0.062037        2048           6          600        ELU
# 31_0      0.042698        1782           4          600        ELU
#
#          metric_name          mean           sem  trial_index
# arm_name
# 20_0             mse  1.101093e-03  3.587943e-05           20
# 1_0              mse  1.200995e-03  2.526300e-05            1
# 16_0             mse  1.201283e-03  3.316098e-05           16
# 21_0             mse  1.258640e-03  2.760059e-05           21
# 6_0              mse  1.276461e-03  3.852698e-05            6
# 18_0             mse  1.321717e-03  3.528556e-05           18
# 19_0             mse  1.326682e-03  3.266715e-05           19
# 14_0             mse  1.401323e-03  3.635680e-05           14
# 8_0              mse  1.432132e-03  3.888215e-05            8
# 5_0              mse  1.747949e-03  2.667329e-05            5
# 13_0             mse  1.795502e-03  3.923932e-05           13
# 17_0             mse  1.832646e-03  3.710002e-05           17
# 9_0              mse  1.899706e-03  4.320503e-05            9
# 4_0              mse  1.936019e-03  5.181617e-05            4
# 23_0             mse  1.950747e-03  2.868478e-05           23
# 3_0              mse  1.958380e-03  3.423446e-05            3
# 11_0             mse  2.016392e-03  3.353273e-05           11
# 12_0             mse  2.344818e-03  3.689339e-05           12
# 15_0             mse  3.168289e-03  4.405518e-05           15
# 32_0             mse  5.418673e-03  4.905893e-05           32
# 24_0             mse  5.463823e-03  4.408518e-04           24
# 36_0             mse  6.307269e-03  9.479290e-05           36
# 2_0              mse  8.623040e-03  8.966719e-05            2
# 33_0             mse  9.190475e-03  1.337475e-04           33
# 40_0             mse  1.650096e-02  1.750446e-04           40
# 35_0             mse  1.866065e-02  1.382560e-04           35
# 10_0             mse  2.475802e-02  2.678083e-04           10
# 42_0             mse  3.185063e-02  3.917143e-04           42
# 37_0             mse  4.208925e-02  2.695446e-04           37
# 43_0             mse  4.724037e-02  4.327962e-04           43
# 38_0             mse  6.843779e-02  4.766026e-04           38
# 7_0              mse  1.281670e-01  1.962316e-03            7
# 25_0             mse  1.310551e-01  2.135385e-03           25
# 41_0             mse  1.781309e-01  2.210463e-03           41
# 44_0             mse  4.577326e-01  6.678339e-03           44
# 28_0             mse  5.828806e+00  1.735706e-01           28
# 26_0             mse  9.476131e+00  9.391623e-01           26
# 27_0             mse  1.290013e+01  1.047229e-01           27
# 29_0             mse  1.384172e+01  3.028662e-01           29
# 30_0             mse  1.442959e+01  2.707353e-01           30
# 39_0             mse  1.495164e+01  1.388059e-01           39
# 0_0              mse  6.149009e+03  1.164816e+02            0
# 34_0             mse  4.188422e+04  1.287305e+03           34
# 22_0             mse  5.717616e+05  4.164881e+04           22
# 31_0             mse  2.821694e+08  3.661112e+06           31

# %%
sns.relplot(data=res_df[:20], x="lr", y="mean")

plt.ylabel("mean MSE")
plt.show()

# %%
sns.relplot(data=res_df[:20], x="batch_size", y="mean")

plt.ylabel("mean MSE")
plt.show()

# %%
sns.relplot(data=res_df[:20], x='hidden_size', y='mean')

plt.ylabel("mean MSE")
plt.show()

# %%
sns.relplot(data=res_df[:20], x='num_layers', y='mean')

plt.ylabel("mean MSE")
plt.show()

# %%
sns.relplot(data=res_df[:25], x='act_fn', y='mean')

plt.ylabel("mean MSE")
plt.savefig('../results/EDA_T_Results_BT/af_mean_scatter.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))

sc = ax.scatter(res_df[:20].lr, 
                res_df[:20].batch_size,
                linewidths=1, alpha=.7,
                edgecolor='k',
                s = 200,
                c=res_df[:20]['mean'])
ax.set_ylabel('Batch size')
ax.set_xlabel('Learning Rate')
cbar = fig.colorbar(sc)
cbar.set_label("Mean MSE")

plt.savefig('../results/EDA_T_Results_BT/bs_lr_mean_2d.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))

sc = ax.scatter(res_df[:20].lr, res_df[:20].batch_size,
            linewidths=1, alpha=.7,
            edgecolor='k',
            s = 200,
            c=res_df[:20]['sem'])
ax.set_ylabel('Batch size')
ax.set_xlabel('Learning Rate')
cbar = fig.colorbar(sc)
cbar.set_label("Sem")

plt.savefig('../results/EDA_T_Results_BT/bs_lr_sem_2d.png')
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(res_df[:20].lr, 
           res_df[:20].batch_size, 
           res_df[:20]['mean'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=res_df[:20]['mean'])
ax.set_ylabel('Batch size', labelpad=6.0)
ax.set_xlabel('Learning Rate', labelpad=6.0)
ax.set_zlabel('Mean MSE', labelpad=12.0)

plt.savefig('../results/EDA_T_Results_BT/bs_lr_mean_3d.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(res_df[:20].lr, 
           res_df[:20].batch_size, 
           res_df[:20]['sem'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=res_df[:20]['sem'])
ax.set_ylabel('Batch size', labelpad=6.0)
ax.set_xlabel('Learning Rate', labelpad=6.0)
ax.set_zlabel('Sem', labelpad=12.0)

plt.savefig('../results/EDA_T_Results_BT/bs_lr_sem_3d.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(res_df[:20].hidden_size, 
           res_df[:20].num_layers, 
           res_df[:20]['mean'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=res_df[:20]['mean'])
ax.set_ylabel('Number of Layers', labelpad=6.0)
ax.set_xlabel('Hidden Size', labelpad=6.0)
ax.set_zlabel('Mean MSE', labelpad=12.0)

plt.savefig('../results/EDA_T_Results_BT/hd_nl_mean_3d.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(res_df[:20].hidden_size, 
           res_df[:20].num_layers, 
           res_df[:20]['sem'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=res_df[:20]['sem'])
ax.set_ylabel('Number of Layers', labelpad=6.0)
ax.set_xlabel('Hidden Size', labelpad=6.0)
ax.set_zlabel('Sem', labelpad=12.0)

plt.savefig('../results/EDA_T_Results_BT/hd_nl_sem_3d.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(res_df[:20].lr, 
           res_df[:20].num_layers, 
           res_df[:20]['mean'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=res_df[:20]['mean'])
ax.set_ylabel('Number of Layers', labelpad=6.0)
ax.set_xlabel('Learning Rate', labelpad=6.0)
ax.set_zlabel('Mean MSE', labelpad=12.0)

plt.savefig('../results/EDA_T_Results_BT/lr_nl_mean_3d.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(res_df[:20].lr, 
           res_df[:20].hidden_size, 
           res_df[:20]['mean'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=res_df[:20]['mean'])
ax.set_ylabel('Hidden Size', labelpad=6.0)
ax.set_xlabel('Learning Rate', labelpad=6.0)
ax.set_zlabel('Mean MSE', labelpad=12.0)

plt.savefig('../results/EDA_T_Results_BT/lr_hd_mean_3d.png', dpi=300)
plt.show()

# %% [markdown]
# - [SO Question](https://stackoverflow.com/questions/59232073/scatter-plot-with-3-variables-in-matplotlib)
