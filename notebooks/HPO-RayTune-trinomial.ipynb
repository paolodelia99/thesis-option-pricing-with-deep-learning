# %% [markdown]
# # Hyperparameters Optimization with ASHA
#
# - Dataset used synthetic trinomial options

# %%
# !pip install -U ray[tune]
# Out:
# Collecting ray[tune]
#   Downloading ray-1.11.0-cp37-cp37m-manylinux2014_x86_64.whl (52.7 MB)
#      |████████████████████████████████| 52.7 MB 79 kB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (21.4.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (7.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.6.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (4.3.3)
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 31.6 MB/s
# Collecting redis>=3.5.0
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 45.3 MB/s
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.21.5)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.13)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.17.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (2.23.0)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 33.3 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.3.5)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (0.8.9)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]) (1.15.0)
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[tune]) (3.10.0.2)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[tune]) (21.3)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[tune]) (4.11.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[tune]) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[tune]) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis>=3.5.0->ray[tune]) (3.0.7)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]) (0.18.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[tune]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (3.0.4)
# Installing collected packages: deprecated, async-timeout, redis, grpcio, tensorboardX, ray
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.44.0
#     Uninstalling grpcio-1.44.0:
#       Successfully uninstalled grpcio-1.44.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed async-timeout-4.0.2 deprecated-1.2.13 grpcio-1.43.0 ray-1.11.0 redis-4.2.2 tensorboardX-2.5

# %%
#@title **Imports**
import os
from functools import partial

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
synthetic_calls_path = '../data/trinomial_synthetic_calls.csv'
synthetic_puts_path = '../data/trinomial_synthetic_puts.csv'
checkpoint_dir = '../models/opt_checkpoints'

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    
    return df

# %%
class OptDataset(Dataset):

  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __getitem__(self, idx):
    return self.X[idx], self.y[idx]

  def __len__(self):
    return len(self.X)

# %%
def preprocessing(df:pd.DataFrame):
  df = pd.get_dummies(df, prefix='', prefix_sep='')
  input_sc = StandardScaler()
  output_sc = StandardScaler()
  input_data = input_sc.fit_transform(df.drop('Option Price', axis=1))
  output_data = output_sc.fit_transform(df['Option Price'].values.reshape(-1, 1))

  return input_data, output_data

# %%
def load_data():
  synthetic_calls = pd.read_csv(synthetic_calls_path, index_col=0)
  synthetic_puts = pd.read_csv(synthetic_puts_path, index_col=0)

  synthetic_calls = reduce_mem_usage(synthetic_calls)
  synthetic_puts = reduce_mem_usage(synthetic_puts)
  
  synthetic_options = pd.concat([synthetic_calls, synthetic_puts], ignore_index=True)
  synthetic_options = shuffle(synthetic_options, random_state=0)
  
  input_data, output_data = preprocessing(synthetic_options)

  train_size = 0.8
  val_size = 0.1

  last_train_idx = int(np.round(len(input_data) * train_size))
  last_val_idx = last_train_idx + int(np.round(len(input_data) * val_size))

  X_train = Variable(torch.Tensor(input_data[0:last_train_idx]))
  X_val = Variable(torch.Tensor(input_data[last_train_idx:last_val_idx]))
  X_test = Variable(torch.Tensor(input_data[last_val_idx:]))

  y_train = Variable(torch.Tensor(output_data[0:last_train_idx]))
  y_val = Variable(torch.Tensor(output_data[last_train_idx:last_val_idx]))
  y_test = Variable(torch.Tensor(output_data[last_val_idx:]))

  return OptDataset(X_train, y_train), OptDataset(X_val, y_val), OptDataset(X_test, y_test)

# %% [markdown]
# # Configurable Model
#
# FCN model with residual blocks, with the following configurable parameters:
#
# - Number of layers
# - Activation function: $[ReLU, LeakyReLU, ELU]$
# - Hidden layer size

# %%
CUDA = torch.cuda.is_available()
device = 'cuda:0' if CUDA else 'cpu'

# %%
class ResBlock(nn.Module):

  def __init__(self, module):
    super(ResBlock, self).__init__()
    self.module = module

  def forward(self, x):
    return self.module(x) + x

# %%
class HiddenLayer(nn.Module):

  def __init__(self, layer_size, act_fn):
      super(HiddenLayer, self).__init__()
      
      if act_fn == 'ReLU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.ReLU())
      elif act_fn == 'LeakyReLU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.LeakyReLU())
      elif act_fn == 'ELU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.ELU())
    
  def forward(self, x):
    return self.layer(x)

# %%
class Net(nn.Module):

  def __init__(self, input_size, output_size, hidden_size, num_layers, act_fn):
    super(Net, self).__init__()
    self.input_size = input_size
    self.output_size = output_size
    self.hidden_size = hidden_size

    if act_fn == 'ReLU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.ReLU())
    elif act_fn == 'LeakyReLU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.LeakyReLU())
    elif act_fn == 'ELU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.ELU())

    self.hidden_layers_list = []

    for i in range(num_layers // 2):
      self.hidden_layers_list.append(
          ResBlock(
            nn.Sequential(
                HiddenLayer(self.hidden_size, act_fn),
                HiddenLayer(self.hidden_size, act_fn)
            )
        )
      )

    self.hidden_layers = nn.Sequential(*self.hidden_layers_list)

    self.net = nn.Sequential(
        self.initial_layer,
        self.hidden_layers,
        nn.Linear(self.hidden_size, self.output_size)
    )
  
  def forward(self, x):
    return self.net(x)

# %%
@torch.no_grad()
def init_xuniform(m):
  if isinstance(m, nn.Linear):
    torch.nn.init.xavier_uniform_(m.weight)
    m.bias.data.fill_(0.01)

# %%
input_size = 7
output_size = 1
number_of_samples = 20

# %%
def train_cifar(config, checkpoint_dir=None):
    net = Net(input_size, output_size, config['hidden_size'], config['num_layers'], config['act_fn'])
    net = net.to(device)
    net.apply(init_xuniform)

    criterion = nn.MSELoss()
    optimizer = optim.Adam(net.parameters(), lr=config["lr"])

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, valset, testset = load_data()

    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)
    valloader = torch.utils.data.DataLoader(
        valset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)

    for epoch in range(25):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 50 == 49:  # print every 50 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                running_loss / epoch_steps))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        for i, data in enumerate(valloader, 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps))
    print("Finished Training")

# %%
def test_accuracy(net, loss_fn):
    trainset, valset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=4, shuffle=False, num_workers=2)

    losses = []
    with torch.no_grad():
        for data in testloader:
            X, y = data
            X, y = X.to(device), y.to(device)
            out = net(X)
            loss = loss_fn(out, y.to(device))
            losses.append(loss.cpu().item())

    return np.array(losses).mean()

# %% [markdown]
# Apart from the networks actitectural parameters, we would like to find the optimal **learning rate** and **batch size**.

# %%
config = {
    "hidden_size": tune.choice([400, 600, 800]),
    "num_layers": tune.choice([4, 6, 8]),
    "act_fn": tune.choice(["ReLU", "LeakyReLU", "ELU"]),
    "lr": tune.loguniform(5e-5, 1e-1),
    "batch_size": tune.choice([512, 1024, 2048])
}

# %%
scheduler = ASHAScheduler(
        metric="loss",
        mode="min",
        max_t=30,
        grace_period=1,
        reduction_factor=2)

# %%
reporter = CLIReporter(
        metric_columns=["loss", "training_iteration"])

# %%
result = tune.run(
        partial(train_cifar, checkpoint_dir=checkpoint_dir),
        resources_per_trial={"cpu": 2, "gpu": 1},
        config=config,
        num_samples=number_of_samples,
        scheduler=scheduler,
        progress_reporter=reporter)
# Out:
# 2022-04-08 08:53:44,424	WARNING experiment.py:256 -- No name detected on trainable. Using DEFAULT.
# 2022-04-08 08:53:44,456	INFO registry.py:70 -- Detected unknown callable for trainable. Converting to class.
# == Status ==
# Current time: 2022-04-08 08:53:45 (running for 00:00:00.55)
# Memory usage on this node: 1.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 16/20 (15 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
#
#
# == Status ==
# Current time: 2022-04-08 08:53:50 (running for 00:00:05.61)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
#
#
# == Status ==
# Current time: 2022-04-08 08:53:55 (running for 00:00:10.61)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
#
#
# == Status ==
# Current time: 2022-04-08 08:54:00 (running for 00:00:15.73)
# Memory usage on this node: 3.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# (func pid=396) /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# (func pid=396)   cpuset_checked))
# (func pid=396) [1,    50] loss: 2115.425
# (func pid=396) [1,   100] loss: 0.243
# == Status ==
# Current time: 2022-04-08 08:54:05 (running for 00:00:20.76)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
#
#
# (func pid=396) [1,   150] loss: 0.012
# (func pid=396) [1,   200] loss: 0.006
# (func pid=396) [1,   250] loss: 0.004
# (func pid=396) [1,   300] loss: 0.003
# (func pid=396) [1,   350] loss: 0.004
# == Status ==
# Current time: 2022-04-08 08:54:10 (running for 00:00:25.80)
# Memory usage on this node: 3.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+
#
#
# Result for DEFAULT_6578f_00000:
#   date: 2022-04-08_08-54-10
#   done: false
#   experiment_id: c2403b94f9fc4e1aa8c166c0da757b6b
#   hostname: 04103710846f
#   iterations_since_restore: 1
#   loss: 0.013430363927036525
#   node_ip: 172.28.0.2
#   pid: 396
#   should_checkpoint: true
#   time_since_restore: 22.227638483047485
#   time_this_iter_s: 22.227638483047485
#   time_total_s: 22.227638483047485
#   timestamp: 1649408050
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6578f_00000
#
# (func pid=396) [2,    50] loss: 0.018
# (func pid=396) [2,   100] loss: 0.008
# (func pid=396) [2,   150] loss: 0.005
# (func pid=396) [2,   200] loss: 0.005
# (func pid=396) [2,   250] loss: 0.003
# (func pid=396) [2,   300] loss: 0.004
# == Status ==
# Current time: 2022-04-08 08:54:15 (running for 00:00:30.94)
# Memory usage on this node: 3.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |      loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 0.0134304 |                    1 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |           |                      |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |           |                      |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |           |                      |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |           |                      |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |           |                      |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |           |                      |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |           |                      |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |           |                      |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |           |                      |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |           |                      |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |           |                      |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |           |                      |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |           |                      |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |           |                      |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |           |                      |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |           |                      |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
#
#
# (func pid=396) [2,   350] loss: 0.002
# Result for DEFAULT_6578f_00000:
#   date: 2022-04-08_08-54-17
#   done: false
#   experiment_id: c2403b94f9fc4e1aa8c166c0da757b6b
#   hostname: 04103710846f
#   iterations_since_restore: 2
#   loss: 0.01526547733694315
#   node_ip: 172.28.0.2
#   pid: 396
#   should_checkpoint: true
#   time_since_restore: 29.224143028259277
#   time_this_iter_s: 6.996504545211792
#   time_total_s: 29.224143028259277
#   timestamp: 1649408057
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 6578f_00000
#
# (func pid=396) [3,    50] loss: 0.017
# (func pid=396) [3,   100] loss: 0.010
# (func pid=396) [3,   150] loss: 0.005
# (func pid=396) [3,   200] loss: 0.003
# (func pid=396) [3,   250] loss: 0.003
# == Status ==
# Current time: 2022-04-08 08:54:21 (running for 00:00:36.93)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: -0.01526547733694315 | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |      loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 0.0152655 |                    2 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |           |                      |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |           |                      |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |           |                      |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |           |                      |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |           |                      |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |           |                      |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |           |                      |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |           |                      |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |           |                      |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |           |                      |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |           |                      |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |           |                      |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |           |                      |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |           |                      |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |           |                      |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |           |                      |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
#
#
# (func pid=396) [3,   300] loss: 0.002
# (func pid=396) [3,   350] loss: 0.003
# Result for DEFAULT_6578f_00000:
#   date: 2022-04-08_08-54-24
#   done: false
#   experiment_id: c2403b94f9fc4e1aa8c166c0da757b6b
#   hostname: 04103710846f
#   iterations_since_restore: 3
#   loss: 0.006672508036717773
#   node_ip: 172.28.0.2
#   pid: 396
#   should_checkpoint: true
#   time_since_restore: 35.57416343688965
#   time_this_iter_s: 6.350020408630371
#   time_total_s: 35.57416343688965
#   timestamp: 1649408064
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 6578f_00000
#
# (func pid=396) [4,    50] loss: 0.013
# (func pid=396) [4,   100] loss: 0.006
# (func pid=396) [4,   150] loss: 0.004
# (func pid=396) [4,   200] loss: 0.003
# == Status ==
# Current time: 2022-04-08 08:54:27 (running for 00:00:42.29)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: -0.01526547733694315 | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+------------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |       loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+------------+----------------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 0.00667251 |                    3 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |            |                      |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |            |                      |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |            |                      |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |            |                      |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |            |                      |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |            |                      |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |            |                      |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |            |                      |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |            |                      |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |            |                      |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |            |                      |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |            |                      |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |            |                      |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |            |                      |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |            |                      |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |            |                      |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+------------+----------------------+
#
#
# (func pid=396) [4,   250] loss: 0.002
# (func pid=396) [4,   300] loss: 0.003
# (func pid=396) [4,   350] loss: 0.002
# Result for DEFAULT_6578f_00000:
#   date: 2022-04-08_08-54-30
#   done: false
#   experiment_id: c2403b94f9fc4e1aa8c166c0da757b6b
#   hostname: 04103710846f
#   iterations_since_restore: 4
#   loss: 0.004680000701919198
#   node_ip: 172.28.0.2
#   pid: 396
#   should_checkpoint: true
#   time_since_restore: 41.98556900024414
#   time_this_iter_s: 6.411405563354492
#   time_total_s: 41.98556900024414
#   timestamp: 1649408070
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 6578f_00000
#
# (func pid=396) [5,    50] loss: 0.017
# (func pid=396) [5,   100] loss: 0.004
# == Status ==
# Current time: 2022-04-08 08:54:32 (running for 00:00:47.68)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.004680000701919198 | Iter 2.000: -0.01526547733694315 | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+---------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |    loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+---------+----------------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 0.00468 |                    4 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |         |                      |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |         |                      |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |         |                      |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |         |                      |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |         |                      |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |         |                      |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |         |                      |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |         |                      |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |         |                      |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |         |                      |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |         |                      |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |         |                      |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |         |                      |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |         |                      |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |         |                      |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |         |                      |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+---------+----------------------+
#
#
# (func pid=396) [5,   150] loss: 0.006
# (func pid=396) [5,   200] loss: 0.004
# (func pid=396) [5,   250] loss: 0.002
# (func pid=396) [5,   300] loss: 0.001
# (func pid=396) [5,   350] loss: 0.002
# Result for DEFAULT_6578f_00000:
#   date: 2022-04-08_08-54-37
#   done: false
#   experiment_id: c2403b94f9fc4e1aa8c166c0da757b6b
#   hostname: 04103710846f
#   iterations_since_restore: 5
#   loss: 0.013940483257174492
#   node_ip: 172.28.0.2
#   pid: 396
#   should_checkpoint: true
#   time_since_restore: 48.38298535346985
#   time_this_iter_s: 6.397416353225708
#   time_total_s: 48.38298535346985
#   timestamp: 1649408077
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: 6578f_00000
#
# == Status ==
# Current time: 2022-04-08 08:54:38 (running for 00:00:53.07)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.004680000701919198 | Iter 2.000: -0.01526547733694315 | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |      loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 0.0139405 |                    5 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |           |                      |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |           |                      |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |           |                      |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |           |                      |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |           |                      |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |           |                      |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |           |                      |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |           |                      |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |           |                      |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |           |                      |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |           |                      |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |           |                      |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |           |                      |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |           |                      |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |           |                      |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |           |                      |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
#
#
# (func pid=396) [6,    50] loss: 0.007
# (func pid=396) [6,   100] loss: 0.004
# (func pid=396) [6,   150] loss: 0.005
# (func pid=396) [6,   200] loss: 0.002
# (func pid=396) [6,   250] loss: 0.002
# (func pid=396) [6,   300] loss: 0.002
# (func pid=396) [6,   350] loss: 0.002
# == Status ==
# Current time: 2022-04-08 08:54:43 (running for 00:00:58.13)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.004680000701919198 | Iter 2.000: -0.01526547733694315 | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |      loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------|
# | DEFAULT_6578f_00000 | RUNNING  | 172.28.0.2:396 | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 0.0139405 |                    5 |
# | DEFAULT_6578f_00001 | PENDING  |                | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |           |                      |
# | DEFAULT_6578f_00002 | PENDING  |                | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |           |                      |
# | DEFAULT_6578f_00003 | PENDING  |                | ELU       |         1024 |           600 | 0.000445563 |            4 |           |                      |
# | DEFAULT_6578f_00004 | PENDING  |                | LeakyReLU |          512 |           600 | 0.00290518  |            6 |           |                      |
# | DEFAULT_6578f_00005 | PENDING  |                | ReLU      |         1024 |           400 | 0.00398561  |            6 |           |                      |
# | DEFAULT_6578f_00006 | PENDING  |                | ELU       |         1024 |           400 | 0.0796883   |            8 |           |                      |
# | DEFAULT_6578f_00007 | PENDING  |                | ReLU      |          512 |           800 | 0.00442159  |            8 |           |                      |
# | DEFAULT_6578f_00008 | PENDING  |                | ReLU      |         1024 |           800 | 0.00243394  |            4 |           |                      |
# | DEFAULT_6578f_00009 | PENDING  |                | ELU       |         2048 |           400 | 0.000757352 |            4 |           |                      |
# | DEFAULT_6578f_00010 | PENDING  |                | ELU       |         1024 |           600 | 0.0190889   |            4 |           |                      |
# | DEFAULT_6578f_00011 | PENDING  |                | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |           |                      |
# | DEFAULT_6578f_00012 | PENDING  |                | ELU       |          512 |           400 | 0.00622938  |            6 |           |                      |
# | DEFAULT_6578f_00013 | PENDING  |                | ELU       |          512 |           400 | 5.9385e-05  |            8 |           |                      |
# | DEFAULT_6578f_00014 | PENDING  |                | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |           |                      |
# | DEFAULT_6578f_00015 | PENDING  |                | ReLU      |         2048 |           800 | 0.0487516   |            6 |           |                      |
# | DEFAULT_6578f_00016 | PENDING  |                | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |           |                      |
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+-----------+----------------------+
#
#
# Result for DEFAULT_6578f_00000:
#   date: 2022-04-08_08-54-43
#   done: false
#   experiment_id: c2403b94f9fc4e1aa8c166c0da757b6b
#   hostname: 04103710846f
#   iterations_since_restore: 6
#   loss: 0.009787676148116589
#   node_ip: 172.28.0.2
#   pid: 396
#   should_checkpoint: true
#   time_since_restore: 54.91430163383484
#   time_this_iter_s: 6.53131628036499
#   time_total_s: 54.91430163383484
#   timestamp: 1649408083
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 6578f_00000
#
# (func pid=396) [7,    50] loss: 0.011
# (func pid=396) [7,   100] loss: 0.003
# (func pid=396) [7,   150] loss: 0.002
# (func pid=396) [7,   200] loss: 0.003
# (func pid=396) [7,   250] loss: 0.001
# (func pid=396) [7,   300] loss: 0.001
# (func pid=396) [7,   350] loss: 0.002
# == Status ==
# Current time: 2022-04-08 08:54:48 (running for 00:01:03.66)
# Memory usage on this node: 3.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.004680000701919198 | Iter 2.000: -0.01526547733694315 | Iter 1.000: -0.013430363927036525
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 17/20 (16 PENDING, 1 RUNNING)
# +---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+------------+----------------------+
# | Trial name          | status   | loc            | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |       loss |   training_iteration |
# |---------------------+----------+----------------+-----------+--------------+---------------+-------------+--------------+------------+----------------------|
# ...
# | DEFAULT_6578f_00015 | TERMINATED | 172.28.0.2:13820 | ReLU      |         2048 |           800 | 0.0487516   |            6 |   41.0324      |                    1 |
# | DEFAULT_6578f_00016 | TERMINATED | 172.28.0.2:13947 | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |    1.10337e-05 |                   25 |
# | DEFAULT_6578f_00017 | TERMINATED | 172.28.0.2:16276 | ELU       |         1024 |           600 | 0.0214229   |            6 |    7.44551     |                    1 |
# | DEFAULT_6578f_00018 | TERMINATED | 172.28.0.2:16411 | LeakyReLU |         1024 |           600 | 0.000281917 |            8 |    0.00025666  |                    8 |
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+
# (func pid=17188) /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# (func pid=17188)   cpuset_checked))
# == Status ==
# Current time: 2022-04-08 09:21:23 (running for 00:27:38.78)
# Memory usage on this node: 3.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=13
# Bracket: Iter 16.000: -3.642434121502447e-05 | Iter 8.000: -7.382442781818099e-05 | Iter 4.000: -0.000132303073478397 | Iter 2.000: -0.00014097547202254645 | Iter 1.000: -0.0014787119603715836
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 20/20 (1 RUNNING, 19 TERMINATED)
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+
# | Trial name          | status     | loc              | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |           loss |   training_iteration |
# |---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------|
# | DEFAULT_6578f_00019 | RUNNING    | 172.28.0.2:17188 | ELU       |         2048 |           800 | 0.0121676   |            8 |                |                      |
# | DEFAULT_6578f_00000 | TERMINATED | 172.28.0.2:396   | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 3129.31        |                   25 |
# | DEFAULT_6578f_00001 | TERMINATED | 172.28.0.2:395   | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |    0.000175528 |                   25 |
# | DEFAULT_6578f_00002 | TERMINATED | 172.28.0.2:4998  | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |    2.30911e-05 |                   25 |
# | DEFAULT_6578f_00003 | TERMINATED | 172.28.0.2:7258  | ELU       |         1024 |           600 | 0.000445563 |            4 |    0.00365902  |                    1 |
# | DEFAULT_6578f_00004 | TERMINATED | 172.28.0.2:7385  | LeakyReLU |          512 |           600 | 0.00290518  |            6 |    0.000245305 |                    4 |
# | DEFAULT_6578f_00005 | TERMINATED | 172.28.0.2:7817  | ReLU      |         1024 |           400 | 0.00398561  |            6 |    0.000236525 |                   25 |
# | DEFAULT_6578f_00006 | TERMINATED | 172.28.0.2:10093 | ELU       |         1024 |           400 | 0.0796883   |            8 |    4.18034e+08 |                    1 |
# | DEFAULT_6578f_00007 | TERMINATED | 172.28.0.2:10218 | ReLU      |          512 |           800 | 0.00442159  |            8 |    0.00073658  |                    4 |
# | DEFAULT_6578f_00008 | TERMINATED | 172.28.0.2:10656 | ReLU      |         1024 |           800 | 0.00243394  |            4 |    0.000314735 |                   25 |
# | DEFAULT_6578f_00009 | TERMINATED | 172.28.0.2:12946 | ELU       |         2048 |           400 | 0.000757352 |            4 |    0.00420467  |                    1 |
# | DEFAULT_6578f_00010 | TERMINATED | 172.28.0.2:13068 | ELU       |         1024 |           600 | 0.0190889   |            4 |    0.201287    |                    1 |
# | DEFAULT_6578f_00011 | TERMINATED | 172.28.0.2:13196 | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |    0.000208697 |                    2 |
# | DEFAULT_6578f_00012 | TERMINATED | 172.28.0.2:13413 | ELU       |          512 |           400 | 0.00622938  |            6 |    0.00589035  |                    1 |
# | DEFAULT_6578f_00013 | TERMINATED | 172.28.0.2:13550 | ELU       |          512 |           400 | 5.9385e-05  |            8 |    0.00147871  |                    1 |
# | DEFAULT_6578f_00014 | TERMINATED | 172.28.0.2:13693 | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |    0.012483    |                    1 |
# | DEFAULT_6578f_00015 | TERMINATED | 172.28.0.2:13820 | ReLU      |         2048 |           800 | 0.0487516   |            6 |   41.0324      |                    1 |
# | DEFAULT_6578f_00016 | TERMINATED | 172.28.0.2:13947 | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |    1.10337e-05 |                   25 |
# | DEFAULT_6578f_00017 | TERMINATED | 172.28.0.2:16276 | ELU       |         1024 |           600 | 0.0214229   |            6 |    7.44551     |                    1 |
# | DEFAULT_6578f_00018 | TERMINATED | 172.28.0.2:16411 | LeakyReLU |         1024 |           600 | 0.000281917 |            8 |    0.00025666  |                    8 |
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+
#
#
# (func pid=17188) [1,    50] loss: 986013.966
# (func pid=17188) [1,   100] loss: 112.855
# == Status ==
# Current time: 2022-04-08 09:21:28 (running for 00:27:43.83)
# Memory usage on this node: 3.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=13
# Bracket: Iter 16.000: -3.642434121502447e-05 | Iter 8.000: -7.382442781818099e-05 | Iter 4.000: -0.000132303073478397 | Iter 2.000: -0.00014097547202254645 | Iter 1.000: -0.0014787119603715836
# Resources requested: 2.0/2 CPUs, 1.0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 20/20 (1 RUNNING, 19 TERMINATED)
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+
# | Trial name          | status     | loc              | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |           loss |   training_iteration |
# |---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------|
# | DEFAULT_6578f_00019 | RUNNING    | 172.28.0.2:17188 | ELU       |         2048 |           800 | 0.0121676   |            8 |                |                      |
# | DEFAULT_6578f_00000 | TERMINATED | 172.28.0.2:396   | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 3129.31        |                   25 |
# | DEFAULT_6578f_00001 | TERMINATED | 172.28.0.2:395   | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |    0.000175528 |                   25 |
# | DEFAULT_6578f_00002 | TERMINATED | 172.28.0.2:4998  | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |    2.30911e-05 |                   25 |
# | DEFAULT_6578f_00003 | TERMINATED | 172.28.0.2:7258  | ELU       |         1024 |           600 | 0.000445563 |            4 |    0.00365902  |                    1 |
# | DEFAULT_6578f_00004 | TERMINATED | 172.28.0.2:7385  | LeakyReLU |          512 |           600 | 0.00290518  |            6 |    0.000245305 |                    4 |
# | DEFAULT_6578f_00005 | TERMINATED | 172.28.0.2:7817  | ReLU      |         1024 |           400 | 0.00398561  |            6 |    0.000236525 |                   25 |
# | DEFAULT_6578f_00006 | TERMINATED | 172.28.0.2:10093 | ELU       |         1024 |           400 | 0.0796883   |            8 |    4.18034e+08 |                    1 |
# | DEFAULT_6578f_00007 | TERMINATED | 172.28.0.2:10218 | ReLU      |          512 |           800 | 0.00442159  |            8 |    0.00073658  |                    4 |
# | DEFAULT_6578f_00008 | TERMINATED | 172.28.0.2:10656 | ReLU      |         1024 |           800 | 0.00243394  |            4 |    0.000314735 |                   25 |
# | DEFAULT_6578f_00009 | TERMINATED | 172.28.0.2:12946 | ELU       |         2048 |           400 | 0.000757352 |            4 |    0.00420467  |                    1 |
# | DEFAULT_6578f_00010 | TERMINATED | 172.28.0.2:13068 | ELU       |         1024 |           600 | 0.0190889   |            4 |    0.201287    |                    1 |
# | DEFAULT_6578f_00011 | TERMINATED | 172.28.0.2:13196 | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |    0.000208697 |                    2 |
# | DEFAULT_6578f_00012 | TERMINATED | 172.28.0.2:13413 | ELU       |          512 |           400 | 0.00622938  |            6 |    0.00589035  |                    1 |
# | DEFAULT_6578f_00013 | TERMINATED | 172.28.0.2:13550 | ELU       |          512 |           400 | 5.9385e-05  |            8 |    0.00147871  |                    1 |
# | DEFAULT_6578f_00014 | TERMINATED | 172.28.0.2:13693 | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |    0.012483    |                    1 |
# | DEFAULT_6578f_00015 | TERMINATED | 172.28.0.2:13820 | ReLU      |         2048 |           800 | 0.0487516   |            6 |   41.0324      |                    1 |
# | DEFAULT_6578f_00016 | TERMINATED | 172.28.0.2:13947 | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |    1.10337e-05 |                   25 |
# | DEFAULT_6578f_00017 | TERMINATED | 172.28.0.2:16276 | ELU       |         1024 |           600 | 0.0214229   |            6 |    7.44551     |                    1 |
# | DEFAULT_6578f_00018 | TERMINATED | 172.28.0.2:16411 | LeakyReLU |         1024 |           600 | 0.000281917 |            8 |    0.00025666  |                    8 |
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+
#
#
# (func pid=17188) [1,   150] loss: 13.718
# 2022-04-08 09:21:33,185	INFO tune.py:639 -- Total run time: 1668.76 seconds (1668.07 seconds for the tuning loop).
# Result for DEFAULT_6578f_00019:
#   date: 2022-04-08_09-21-33
#   done: true
#   experiment_id: a8449a69be4448d28bfb43d19ba2373d
#   hostname: 04103710846f
#   iterations_since_restore: 1
#   loss: 19.87030433654785
#   node_ip: 172.28.0.2
#   pid: 17188
#   should_checkpoint: true
#   time_since_restore: 15.653190612792969
#   time_this_iter_s: 15.653190612792969
#   time_total_s: 15.653190612792969
#   timestamp: 1649409693
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6578f_00019
#
# == Status ==
# Current time: 2022-04-08 09:21:33 (running for 00:27:48.08)
# Memory usage on this node: 2.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=14
# Bracket: Iter 16.000: -3.642434121502447e-05 | Iter 8.000: -7.382442781818099e-05 | Iter 4.000: -0.000132303073478397 | Iter 2.000: -0.00014097547202254645 | Iter 1.000: -0.0025688640761654825
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/6.99 GiB heap, 0.0/3.49 GiB objects (0.0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT_2022-04-08_08-53-44
# Number of trials: 20/20 (20 TERMINATED)
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+
# | Trial name          | status     | loc              | act_fn    |   batch_size |   hidden_size |          lr |   num_layers |           loss |   training_iteration |
# |---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------|
# | DEFAULT_6578f_00000 | TERMINATED | 172.28.0.2:396   | LeakyReLU |         1024 |           600 | 0.0182931   |            4 | 3129.31        |                   25 |
# | DEFAULT_6578f_00001 | TERMINATED | 172.28.0.2:395   | LeakyReLU |         1024 |           800 | 0.00148146  |            6 |    0.000175528 |                   25 |
# | DEFAULT_6578f_00002 | TERMINATED | 172.28.0.2:4998  | LeakyReLU |         1024 |           400 | 8.59109e-05 |            6 |    2.30911e-05 |                   25 |
# | DEFAULT_6578f_00003 | TERMINATED | 172.28.0.2:7258  | ELU       |         1024 |           600 | 0.000445563 |            4 |    0.00365902  |                    1 |
# | DEFAULT_6578f_00004 | TERMINATED | 172.28.0.2:7385  | LeakyReLU |          512 |           600 | 0.00290518  |            6 |    0.000245305 |                    4 |
# | DEFAULT_6578f_00005 | TERMINATED | 172.28.0.2:7817  | ReLU      |         1024 |           400 | 0.00398561  |            6 |    0.000236525 |                   25 |
# | DEFAULT_6578f_00006 | TERMINATED | 172.28.0.2:10093 | ELU       |         1024 |           400 | 0.0796883   |            8 |    4.18034e+08 |                    1 |
# | DEFAULT_6578f_00007 | TERMINATED | 172.28.0.2:10218 | ReLU      |          512 |           800 | 0.00442159  |            8 |    0.00073658  |                    4 |
# | DEFAULT_6578f_00008 | TERMINATED | 172.28.0.2:10656 | ReLU      |         1024 |           800 | 0.00243394  |            4 |    0.000314735 |                   25 |
# | DEFAULT_6578f_00009 | TERMINATED | 172.28.0.2:12946 | ELU       |         2048 |           400 | 0.000757352 |            4 |    0.00420467  |                    1 |
# | DEFAULT_6578f_00010 | TERMINATED | 172.28.0.2:13068 | ELU       |         1024 |           600 | 0.0190889   |            4 |    0.201287    |                    1 |
# | DEFAULT_6578f_00011 | TERMINATED | 172.28.0.2:13196 | LeakyReLU |         1024 |           400 | 0.000238255 |            4 |    0.000208697 |                    2 |
# | DEFAULT_6578f_00012 | TERMINATED | 172.28.0.2:13413 | ELU       |          512 |           400 | 0.00622938  |            6 |    0.00589035  |                    1 |
# | DEFAULT_6578f_00013 | TERMINATED | 172.28.0.2:13550 | ELU       |          512 |           400 | 5.9385e-05  |            8 |    0.00147871  |                    1 |
# | DEFAULT_6578f_00014 | TERMINATED | 172.28.0.2:13693 | LeakyReLU |         2048 |           800 | 0.00741057  |            8 |    0.012483    |                    1 |
# | DEFAULT_6578f_00015 | TERMINATED | 172.28.0.2:13820 | ReLU      |         2048 |           800 | 0.0487516   |            6 |   41.0324      |                    1 |
# | DEFAULT_6578f_00016 | TERMINATED | 172.28.0.2:13947 | LeakyReLU |         1024 |           600 | 0.000427454 |            4 |    1.10337e-05 |                   25 |
# | DEFAULT_6578f_00017 | TERMINATED | 172.28.0.2:16276 | ELU       |         1024 |           600 | 0.0214229   |            6 |    7.44551     |                    1 |
# | DEFAULT_6578f_00018 | TERMINATED | 172.28.0.2:16411 | LeakyReLU |         1024 |           600 | 0.000281917 |            8 |    0.00025666  |                    8 |
# | DEFAULT_6578f_00019 | TERMINATED | 172.28.0.2:17188 | ELU       |         2048 |           800 | 0.0121676   |            8 |   19.8703      |                    1 |
# +---------------------+------------+------------------+-----------+--------------+---------------+-------------+--------------+----------------+----------------------+

# %%
res_df = result.results_df
res_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ray/tune/analysis/experiment_analysis.py:282: UserWarning: Dataframes will use '/' instead of '.' to delimit nested result keys in future versions of Ray. For forward compatibility, set the environment variable TUNE_RESULT_DELIM='/'
#   "Dataframes will use '/' instead of '.' to delimit "
#                      loss  time_this_iter_s  should_checkpoint  done  \
# trial_id
# 6578f_00000  3.129306e+03          7.088722               True  True
# 6578f_00001  1.755282e-04         11.586078               True  True
# 6578f_00002  2.309114e-05          6.689006               True  True
# 6578f_00003  3.659016e-03         11.050263               True  True
# 6578f_00004  2.453048e-04         11.589147               True  True
# 6578f_00005  2.365250e-04          6.844717               True  True
# 6578f_00006  4.180335e+08         11.726375               True  True
# 6578f_00007  7.365799e-04         16.881970               True  True
# 6578f_00008  3.147351e-04          8.354793               True  True
# 6578f_00009  4.204668e-03          9.337440               True  True
# 6578f_00010  2.012872e-01         11.020704               True  True
# 6578f_00011  2.086975e-04          6.905680               True  True
# 6578f_00012  5.890346e-03         14.261845               True  True
# 6578f_00013  1.478712e-03         15.577951               True  True
# 6578f_00014  1.248303e-02         15.828911               True  True
# 6578f_00015  4.103238e+01         13.049099               True  True
# 6578f_00016  1.103375e-05          7.563665               True  True
# 6578f_00017  7.445510e+00         12.093155               True  True
# 6578f_00018  2.566597e-04          9.330349               True  True
# 6578f_00019  1.987030e+01         15.653191               True  True
#
#             timesteps_total episodes_total  training_iteration  \
# trial_id
# 6578f_00000            None           None                  25
# 6578f_00001            None           None                  25
# 6578f_00002            None           None                  25
# 6578f_00003            None           None                   1
# 6578f_00004            None           None                   4
# 6578f_00005            None           None                  25
# 6578f_00006            None           None                   1
# 6578f_00007            None           None                   4
# 6578f_00008            None           None                  25
# 6578f_00009            None           None                   1
# 6578f_00010            None           None                   1
# 6578f_00011            None           None                   2
# 6578f_00012            None           None                   1
# 6578f_00013            None           None                   1
# 6578f_00014            None           None                   1
# 6578f_00015            None           None                   1
# 6578f_00016            None           None                  25
# 6578f_00017            None           None                   1
# 6578f_00018            None           None                   8
# 6578f_00019            None           None                   1
#
#                                 experiment_id                 date  \
# trial_id
# 6578f_00000  c2403b94f9fc4e1aa8c166c0da757b6b  2022-04-08_08-56-53
# 6578f_00001  4102f55201eb447f886cbcfd49cf6dba  2022-04-08_09-01-38
# 6578f_00002  4f6e49b8c0f940e2be60682de53a34f6  2022-04-08_09-04-37
# 6578f_00003  9664d2f1cff347989894c560d084c62c  2022-04-08_09-04-54
# 6578f_00004  4a8bc69df3934b22b667a620122ca910  2022-04-08_09-05-49
# 6578f_00005  fafd69c349b94fb4b249a59cb188220a  2022-04-08_09-08-51
# 6578f_00006  abfab65206f94f0485d89c5a197a0b2c  2022-04-08_09-09-08
# 6578f_00007  9591b3c3c2d3462f9da9ba7404648e08  2022-04-08_09-10-25
# 6578f_00008  9189b068770241ab90fa067a7ee233a5  2022-04-08_09-14-07
# 6578f_00009  fdf01a6fa1434194b417a1a1a6fc934e  2022-04-08_09-14-22
# 6578f_00010  c8f86a30209c44f58cbfe10d9ebeca5a  2022-04-08_09-14-39
# 6578f_00011  aca2a3979c674f539a9fed40af2af077  2022-04-08_09-15-02
# 6578f_00012  ba8b5e050d274ff890ab4ce931630adb  2022-04-08_09-15-22
# 6578f_00013  ee4075130d6640f086064e5393818210  2022-04-08_09-15-43
# 6578f_00014  82b1f99a49834c489509d218cb2497e6  2022-04-08_09-16-05
# 6578f_00015  3d00f83c565b4467b9c3fdebeb1c3a7b  2022-04-08_09-16-24
# 6578f_00016  3dad3f61c71c42ceae0803674e83b40c  2022-04-08_09-19-28
# 6578f_00017  d287c0605aea4211ba58fed0af7f4fa7  2022-04-08_09-19-46
# 6578f_00018  5852ace494394e869bd4306b44deebb1  2022-04-08_09-21-11
# 6578f_00019  a8449a69be4448d28bfb43d19ba2373d  2022-04-08_09-21-33
#
#               timestamp  ...     node_ip  time_since_restore  \
# trial_id                 ...
# 6578f_00000  1649408213  ...  172.28.0.2          185.159463
# 6578f_00001  1649408498  ...  172.28.0.2          279.885255
# 6578f_00002  1649408677  ...  172.28.0.2          173.042274
# 6578f_00003  1649408694  ...  172.28.0.2           11.050263
# 6578f_00004  1649408749  ...  172.28.0.2           49.214201
# 6578f_00005  1649408931  ...  172.28.0.2          176.528298
# 6578f_00006  1649408948  ...  172.28.0.2           11.726375
# 6578f_00007  1649409025  ...  172.28.0.2           70.733349
# 6578f_00008  1649409247  ...  172.28.0.2          215.672403
# 6578f_00009  1649409262  ...  172.28.0.2            9.337440
# 6578f_00010  1649409279  ...  172.28.0.2           11.020704
# 6578f_00011  1649409302  ...  172.28.0.2           17.540402
# 6578f_00012  1649409322  ...  172.28.0.2           14.261845
# 6578f_00013  1649409343  ...  172.28.0.2           15.577951
# 6578f_00014  1649409365  ...  172.28.0.2           15.828911
# 6578f_00015  1649409384  ...  172.28.0.2           13.049099
# 6578f_00016  1649409568  ...  172.28.0.2          178.184902
# 6578f_00017  1649409586  ...  172.28.0.2           12.093155
# 6578f_00018  1649409671  ...  172.28.0.2           79.348901
# 6578f_00019  1649409693  ...  172.28.0.2           15.653191
#
#             timesteps_since_restore iterations_since_restore  \
# trial_id
# 6578f_00000                       0                       25
# 6578f_00001                       0                       25
# 6578f_00002                       0                       25
# 6578f_00003                       0                        1
# 6578f_00004                       0                        4
# 6578f_00005                       0                       25
# 6578f_00006                       0                        1
# 6578f_00007                       0                        4
# 6578f_00008                       0                       25
# 6578f_00009                       0                        1
# 6578f_00010                       0                        1
# 6578f_00011                       0                        2
# 6578f_00012                       0                        1
# 6578f_00013                       0                        1
# 6578f_00014                       0                        1
# 6578f_00015                       0                        1
# 6578f_00016                       0                       25
# 6578f_00017                       0                        1
# 6578f_00018                       0                        8
# 6578f_00019                       0                        1
#
#                                                 experiment_tag  \
# trial_id
# 6578f_00000  0_act_fn=LeakyReLU,batch_size=1024,hidden_size...
# 6578f_00001  1_act_fn=LeakyReLU,batch_size=1024,hidden_size...
# 6578f_00002  2_act_fn=LeakyReLU,batch_size=1024,hidden_size...
# 6578f_00003  3_act_fn=ELU,batch_size=1024,hidden_size=600,l...
# 6578f_00004  4_act_fn=LeakyReLU,batch_size=512,hidden_size=...
# 6578f_00005  5_act_fn=ReLU,batch_size=1024,hidden_size=400,...
# 6578f_00006  6_act_fn=ELU,batch_size=1024,hidden_size=400,l...
# 6578f_00007  7_act_fn=ReLU,batch_size=512,hidden_size=800,l...
# 6578f_00008  8_act_fn=ReLU,batch_size=1024,hidden_size=800,...
# 6578f_00009  9_act_fn=ELU,batch_size=2048,hidden_size=400,l...
# 6578f_00010  10_act_fn=ELU,batch_size=1024,hidden_size=600,...
# 6578f_00011  11_act_fn=LeakyReLU,batch_size=1024,hidden_siz...
# 6578f_00012  12_act_fn=ELU,batch_size=512,hidden_size=400,l...
# 6578f_00013  13_act_fn=ELU,batch_size=512,hidden_size=400,l...
# 6578f_00014  14_act_fn=LeakyReLU,batch_size=2048,hidden_siz...
# 6578f_00015  15_act_fn=ReLU,batch_size=2048,hidden_size=800...
# 6578f_00016  16_act_fn=LeakyReLU,batch_size=1024,hidden_siz...
# 6578f_00017  17_act_fn=ELU,batch_size=1024,hidden_size=600,...
# 6578f_00018  18_act_fn=LeakyReLU,batch_size=1024,hidden_siz...
# 6578f_00019  19_act_fn=ELU,batch_size=2048,hidden_size=800,...
#
#              config.hidden_size  config.num_layers config.act_fn  config.lr  \
# trial_id
# 6578f_00000                 600                  4     LeakyReLU   0.018293
# 6578f_00001                 800                  6     LeakyReLU   0.001481
# 6578f_00002                 400                  6     LeakyReLU   0.000086
# 6578f_00003                 600                  4           ELU   0.000446
# 6578f_00004                 600                  6     LeakyReLU   0.002905
# 6578f_00005                 400                  6          ReLU   0.003986
# 6578f_00006                 400                  8           ELU   0.079688
# 6578f_00007                 800                  8          ReLU   0.004422
# 6578f_00008                 800                  4          ReLU   0.002434
# 6578f_00009                 400                  4           ELU   0.000757
# 6578f_00010                 600                  4           ELU   0.019089
# 6578f_00011                 400                  4     LeakyReLU   0.000238
# 6578f_00012                 400                  6           ELU   0.006229
# 6578f_00013                 400                  8           ELU   0.000059
# 6578f_00014                 800                  8     LeakyReLU   0.007411
# 6578f_00015                 800                  6          ReLU   0.048752
# 6578f_00016                 600                  4     LeakyReLU   0.000427
# 6578f_00017                 600                  6           ELU   0.021423
# 6578f_00018                 600                  8     LeakyReLU   0.000282
# 6578f_00019                 800                  8           ELU   0.012168
#
#              config.batch_size
# trial_id
# 6578f_00000               1024
# 6578f_00001               1024
# 6578f_00002               1024
# 6578f_00003               1024
# 6578f_00004                512
# 6578f_00005               1024
# 6578f_00006               1024
# 6578f_00007                512
# 6578f_00008               1024
# 6578f_00009               2048
# 6578f_00010               1024
# 6578f_00011               1024
# 6578f_00012                512
# 6578f_00013                512
# 6578f_00014               2048
# 6578f_00015               2048
# 6578f_00016               1024
# 6578f_00017               1024
# 6578f_00018               1024
# 6578f_00019               2048
#
# [20 rows x 23 columns]

# %%
res_df.to_csv('../results/asha_trinomial_results.csv')

# %%
best_trial = result.get_best_trial("loss", "min", "last")
print("Best trial config: {}".format(best_trial.config))
print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
# Out:
# Best trial config: {'hidden_size': 600, 'num_layers': 4, 'act_fn': 'LeakyReLU', 'lr': 0.00042745369696213476, 'batch_size': 1024}
# Best trial final validation loss: 1.1033747832698281e-05

# %%
best_trained_model = Net(
    input_size, 
    output_size, 
    best_trial.config['hidden_size'], 
    best_trial.config['num_layers'], 
    best_trial.config['act_fn'])

# %%
best_trained_model = best_trained_model.to(device)
best_checkpoint_dir = best_trial.checkpoint.value
model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
best_trained_model.load_state_dict(model_state)

loss_fn = nn.MSELoss()
test_acc = test_accuracy(best_trained_model, loss_fn)
print("Best trial test set accuracy: {}".format(test_acc))
# Out:
# Best trial test set accuracy: 1.0951483459672485e-05

# %% [markdown]
# - [Pytorch Tutorial](https://pytorch.org/tutorials/beginner/hyperparameter_tuning_tutorial.html)
# - [ASHA Paper](https://openreview.net/pdf?id=S1MAriC5F7)
