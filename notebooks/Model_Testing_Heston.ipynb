# %% [markdown]
# # Models Testing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torch.nn.modules.activation import LeakyReLU

# %%
# Set seeds
torch.manual_seed(0)
np.random.seed(0)

# %%
synthetic_calls_path = '/content/drive/MyDrive/Progetto Stage/data/heston_mc_synthetic_calls_tot.csv'
synthetic_puts_path = '/content/drive/MyDrive/Progetto Stage/data/heston_mc_synthetic_puts_tot.csv'

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    
    return df

# %%
synthetic_calls = pd.read_csv(synthetic_calls_path, index_col=0)
synthetic_puts = pd.read_csv(synthetic_puts_path, index_col=0)

synthetic_calls = reduce_mem_usage(synthetic_calls)
synthetic_puts = reduce_mem_usage(synthetic_puts)

# %%
synthetic_options = pd.concat([synthetic_calls, synthetic_puts], axis=0)
synthetic_options = shuffle(synthetic_options, random_state=0)
synthetic_options = synthetic_options.reset_index()
synthetic_options = synthetic_options.drop('index', axis=1)

# %%
synthetic_options
# Out:
#         Price  Strike     Kappa       Rho     Theta        Xi       V_0  \
# 0         100   143.0  1.728516  0.158936  0.158936  0.158936  0.158936
# 1         100    68.0  1.207031  0.547852  0.547852  0.547852  0.547852
# 2         100   127.0  0.997070  0.672363  0.672363  0.672363  0.672363
# 3         100   140.0  1.411133  0.494629  0.494629  0.494629  0.494629
# 4         100    60.0  0.271729  0.102478  0.102478  0.102478  0.102478
# ...       ...     ...       ...       ...       ...       ...       ...
# 807995    100    71.0  0.553223  0.829590  0.829590  0.829590  0.829590
# 807996    100    57.0  1.411133  0.825684  0.825684  0.825684  0.825684
# 807997    100   135.0  1.419922  1.062500  1.062500  1.062500  1.062500
# 807998    100    64.0  1.577148  1.038086  1.038086  1.038086  1.038086
# 807999    100   135.0  1.232422  0.161743  0.161743  0.161743  0.161743
#
#         Interest Rate  Time to Expiration  Option Price  C  P
# 0            0.058685            0.158936      0.000000  1  0
# 1            0.073486            0.547852      0.957520  0  1
# 2            0.014740            0.672363     26.546875  0  1
# 3            0.052063            0.494629     38.750000  0  1
# 4            0.035553            0.102478     38.593750  1  0
# ...               ...                 ...           ... .. ..
# 807995       0.076904            0.829590     27.875000  1  0
# 807996       0.084656            0.825684     42.437500  1  0
# 807997       0.073792            1.062500      2.345703  1  0
# 807998       0.091187            1.038086      0.202026  0  1
# 807999       0.038239            0.161743      0.061554  1  0
#
# [808000 rows x 12 columns]

# %% [markdown]
# # Preprocessing

# %%
synthetic_options = pd.get_dummies(synthetic_options, prefix='', prefix_sep='')

# %%
input_sc = StandardScaler()
output_sc = StandardScaler()
input_data = input_sc.fit_transform(synthetic_options.drop('Option Price', axis=1))
output_data = output_sc.fit_transform(synthetic_options['Option Price'].values.reshape(-1, 1))

train_size = 0.8
val_size = 0.1

last_train_idx = int(np.round(len(input_data) * train_size))
last_val_idx = last_train_idx + int(np.round(len(input_data) * val_size))

X_train = input_data[0:last_train_idx]
X_val = input_data[last_train_idx:last_val_idx]
X_test = input_data[last_val_idx:]

y_train = output_data[0:last_train_idx]
y_val = output_data[last_train_idx:last_val_idx]
y_test = output_data[last_val_idx:]

# %%
X_train = Variable(torch.Tensor(X_train))
X_val = Variable(torch.Tensor(X_val))
X_test = Variable(torch.Tensor(X_test))

y_train = Variable(torch.Tensor(y_train))
y_val = Variable(torch.Tensor(y_val))
y_test = Variable(torch.Tensor(y_test))

# %% [markdown]
# # Model

# %%
CUDA = torch.cuda.is_available()
device = 'cuda:0' if CUDA else 'cpu'

# %%
class ResBlock(nn.Module):

  def __init__(self, module):
    super(ResBlock, self).__init__()
    self.module = module

  def forward(self, x):
    return self.module(x) + x

# %%
class HiddenLayer(nn.Module):

  def __init__(self, layer_size, act_fn):
      super(HiddenLayer, self).__init__()
      
      if act_fn == 'ReLU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.ReLU())
      elif act_fn == 'LeakyReLU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.LeakyReLU())
      elif act_fn == 'ELU':
        self.layer = nn.Sequential(
          nn.Linear(layer_size, layer_size),
          nn.ELU())
    
  def forward(self, x):
    return self.layer(x)

# %%
class Net(nn.Module):

  def __init__(self, input_size, output_size, hidden_size, num_layers, act_fn):
    super(Net, self).__init__()
    self.input_size = input_size
    self.output_size = output_size
    self.hidden_size = hidden_size

    if act_fn == 'ReLU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.ReLU())
    elif act_fn == 'LeakyReLU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.LeakyReLU())
    elif act_fn == 'ELU':
      self.initial_layer = nn.Sequential(
          nn.Linear(self.input_size, self.hidden_size),
          nn.ELU())

    self.hidden_layers_list = []

    for i in range(num_layers // 2):
      self.hidden_layers_list.append(
          ResBlock(
            nn.Sequential(
                HiddenLayer(self.hidden_size, act_fn),
                HiddenLayer(self.hidden_size, act_fn)
            )
        )
      )

    self.hidden_layers = nn.Sequential(*self.hidden_layers_list)

    self.net = nn.Sequential(
        self.initial_layer,
        self.hidden_layers,
        nn.Linear(self.hidden_size, self.output_size)
    )
  
  def forward(self, x):
    return self.net(x)

# %%
def init_weights(m, init_m: str):

  @torch.no_grad()
  def init_uniform(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.uniform_(m.weight)
      m.bias.data.fill_(0.01)

  @torch.no_grad()
  def init_normal(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.normal_(m.weight)
      m.bias.data.fill_(0.01)

  @torch.no_grad()
  def init_xuniform(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.xavier_uniform_(m.weight)
      m.bias.data.fill_(0.01)

  @torch.no_grad()
  def init_xnormal(m):
    if isinstance(m, nn.Linear):
      torch.nn.init.xavier_normal_(m.weight)
      m.bias.data.fill_(0.01)

  if init_m == 'uniform':
    m.apply(init_uniform)
  elif init_m == 'normal':
    m.apply(init_normal)
  elif init_m == 'xaiver uniform':
    m.apply(init_xuniform)
  elif init_m == 'xavier normal':
    m.apply(init_xnormal)

# %% [markdown]
# # Best models from cross validation

# %%
best_models = [
               {'n_hidden': 400, 'n_layers': 8, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 4, 'act_fun': 'ReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 4, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 6, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'},
               {'n_hidden': 400, 'n_layers': 8, 'act_fun': 'LeakyReLU', 'init_method': 'xavier uniform'}
]

# %% [markdown]
# # Training

# %%
input_size = 11
output_size = 1
batch_size = 1024
epochs = 125
lr = 1e-4

loss_fn = nn.MSELoss()

# %%
class OptDataset(Dataset):

  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __getitem__(self, idx):
    return self.X[idx], self.y[idx]

  def __len__(self):
    return len(self.X)

# %%
def evaluate(model, loss_fn, X, y):
  model.eval()
  with torch.no_grad():
    out = model(X.to(device))
    loss = loss_fn(out, y.to(device))
    return loss.item()

# %%
def mape_loss(y_pred, y):
  return sum([np.abs(y_i - hy_i) / y_i for y_i, hy_i in zip(y_pred, y)]) / len(y_pred)

# %%
def get_mape_loss(model, X, y):
  model.eval()
  with torch.no_grad():
    out = model(X.to(device))
    loss = mape_loss(
        out.squeeze().cpu().detach().numpy(), 
        y.squeeze().cpu().detach().numpy())
    return loss

# %%
def test_models(
  models_dict,
  epochs,
  batch_size,
  X_train,
  y_train,
  X_val,
  y_val,
  X_test,
  y_test,
  loss_fn
):
  testing_results = pd.DataFrame(columns=
                               ['hidden_size',
                                'n_layers',
                                'act_fun',
                                'init_methods',
                                'mean_val_result',
                                'std_val_result',
                                'test_mse',
                                'test_mae',
                                'test_rmse',
                                'test_mape'])

  for model_dict in models_dict:
    model = Net(input_size,
                output_size, 
                model_dict['n_hidden'], 
                model_dict['n_layers'], 
                model_dict['act_fun']).to(device)
    init_weights(model, model_dict['init_method'])
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    validation_losses = []
    test_res = {
        'hidden_size': model_dict['n_hidden'],
        'n_layers': model_dict['n_layers'],
        'act_fun': model_dict['act_fun'],
        'init_methods': model_dict['init_method']
    }

    print('Model: ', test_res)

    for epoch in range(epochs):
      model.train()
      total_loss = 0
      start_time = time.time()
      i = 0

      for batch, batch_labels in DataLoader(OptDataset(X_train, y_train), batch_size):
        out = model(batch.to(device))
        optimizer.zero_grad()

        loss = loss_fn(out, batch_labels.to(device))
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        if i > 0 and i % 25 == 0:
          avg_loss = total_loss / 50
          elapsed = time.time() - start_time
          print('| Epoch {:3d} | {:5d}/{:5d} batches | lr {:2.5f} | ms/batch {:5.2f} | '
                  'loss {:5.8f}'.format(
              epoch, i, len(X_train) // batch_size+1, lr, elapsed * 1000 / 50,
              avg_loss))
          start_time = time.time()
          total_loss = 0
        
        i += 1

      validation_losses.append(evaluate(model, loss_fn, X_val, y_val))
    
    mse_test = evaluate(model, loss_fn, X_test, y_test)
    mae_loss = nn.L1Loss()
    mae_test = evaluate(model, mae_loss, X_test, y_test)
    mape_test = get_mape_loss(model, X_test, y_test)
    validation_losses = np.array(validation_losses)
    test_res['mean_val_result'] = validation_losses.mean()
    test_res['std_val_result'] = validation_losses.std()
    test_res['test_mse'] = mse_test
    test_res['test_mae'] = mae_test
    test_res['test_rmse'] = np.sqrt(mse_test)
    test_res['test_mape'] = mape_test

    testing_results = testing_results.append(test_res, ignore_index=True)

  return testing_results

# %%
testing_results = test_models(best_models,
            epochs,
            batch_size,
             X_train,
            y_train,
            X_val,
            y_val,
            X_test,
            y_test,
            loss_fn)
# Out:
# Model:  {'hidden_size': 400, 'n_layers': 8, 'act_fun': 'LeakyReLU', 'init_methods': 'xavier uniform'}
# | Epoch   0 |    25/  632 batches | lr 0.00010 | ms/batch 11.60 | loss 0.27984494
# | Epoch   5 |   450/  632 batches | lr 0.00010 | ms/batch  6.42 | loss 0.00245206
# | Epoch   5 |   475/  632 batches | lr 0.00010 | ms/batch  7.66 | loss 0.00238270
# | Epoch   5 |   500/  632 batches | lr 0.00010 | ms/batch  7.68 | loss 0.00240451
# | Epoch   5 |   525/  632 batches | lr 0.00010 | ms/batch  7.73 | loss 0.00234216
# | Epoch   5 |   550/  632 batches | lr 0.00010 | ms/batch  6.51 | loss 0.00246015
# | Epoch   5 |   575/  632 batches | lr 0.00010 | ms/batch  7.67 | loss 0.00237228
# | Epoch   5 |   600/  632 batches | lr 0.00010 | ms/batch  7.92 | loss 0.00227711
# | Epoch   5 |   625/  632 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00231046
# | Epoch   6 |    25/  632 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00237139
# | Epoch   6 |    50/  632 batches | lr 0.00010 | ms/batch  7.97 | loss 0.00234003
# | Epoch   6 |    75/  632 batches | lr 0.00010 | ms/batch  6.91 | loss 0.00240857
# | Epoch   6 |   100/  632 batches | lr 0.00010 | ms/batch  8.12 | loss 0.00236834
# | Epoch   6 |   125/  632 batches | lr 0.00010 | ms/batch  8.80 | loss 0.00234246
# | Epoch   6 |   150/  632 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00234878
# | Epoch   6 |   175/  632 batches | lr 0.00010 | ms/batch  7.99 | loss 0.00245736
# | Epoch   6 |   200/  632 batches | lr 0.00010 | ms/batch  8.35 | loss 0.00234817
# | Epoch   6 |   225/  632 batches | lr 0.00010 | ms/batch  7.99 | loss 0.00226270
# | Epoch   6 |   250/  632 batches | lr 0.00010 | ms/batch  6.49 | loss 0.00238701
# | Epoch   6 |   275/  632 batches | lr 0.00010 | ms/batch  8.26 | loss 0.00227851
# | Epoch   6 |   300/  632 batches | lr 0.00010 | ms/batch  8.06 | loss 0.00230236
# | Epoch   6 |   325/  632 batches | lr 0.00010 | ms/batch  6.95 | loss 0.00236302
# | Epoch   6 |   350/  632 batches | lr 0.00010 | ms/batch  7.81 | loss 0.00239049
# | Epoch   6 |   375/  632 batches | lr 0.00010 | ms/batch  7.81 | loss 0.00239621
# | Epoch   6 |   400/  632 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00229984
# | Epoch   6 |   425/  632 batches | lr 0.00010 | ms/batch  8.15 | loss 0.00232535
# | Epoch   6 |   450/  632 batches | lr 0.00010 | ms/batch  7.86 | loss 0.00244061
# | Epoch   6 |   475/  632 batches | lr 0.00010 | ms/batch  8.19 | loss 0.00238337
# | Epoch   6 |   500/  632 batches | lr 0.00010 | ms/batch  6.84 | loss 0.00239511
# | Epoch   6 |   525/  632 batches | lr 0.00010 | ms/batch  8.48 | loss 0.00235096
# | Epoch   6 |   550/  632 batches | lr 0.00010 | ms/batch  8.13 | loss 0.00248081
# | Epoch   6 |   575/  632 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00236203
# | Epoch   6 |   600/  632 batches | lr 0.00010 | ms/batch  8.30 | loss 0.00226431
# | Epoch   6 |   625/  632 batches | lr 0.00010 | ms/batch  8.20 | loss 0.00232045
# | Epoch   7 |    25/  632 batches | lr 0.00010 | ms/batch  7.26 | loss 0.00236419
# | Epoch   7 |    50/  632 batches | lr 0.00010 | ms/batch  8.20 | loss 0.00233059
# | Epoch   7 |    75/  632 batches | lr 0.00010 | ms/batch  8.34 | loss 0.
batches | lr 0.00010 | ms/batch  6.67 | loss 0.00231680
# | Epoch  13 |   125/  632 batches | lr 0.00010 | ms/batch  7.48 | loss 0.00227465
# | Epoch  13 |   150/  632 batches | lr 0.00010 | ms/batch  8.21 | loss 0.00232710
# | Epoch  13 |   175/  632 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00224385
# | Epoch  13 |   200/  632 batches | lr 0.00010 | ms/batch  8.08 | loss 0.00224017
# | Epoch  13 |   225/  632 batches | lr 0.00010 | ms/batch  7.84 | loss 0.00223340
# | Epoch  13 |   250/  632 batches | lr 0.00010 | ms/batch  7.79 | loss 0.00232963
# | Epoch  13 |   275/  632 batches | lr 0.00010 | ms/batch  7.00 | loss 0.00222041
# | Epoch  13 |   300/  632 batches | lr 0.00010 | ms/batch  8.74 | loss 0.00224910
# | Epoch  13 |   325/  632 batches | lr 0.00010 | ms/batch  8.18 | loss 0.00231829
# | Epoch  13 |   350/  632 batches | lr 0.00010 | ms/batch  7.03 | loss 0.00228440
# | Epoch  13 |   375/  632 batches | lr 0.00010 | ms/batch  7.63 | loss 0.00229582
# | Epoch  13 |   400/  632 batches | lr 0.00010 | ms/batch  7.95 | loss 0.00223343
# | Epoch  13 |   425/  632 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00228628
# | Epoch  13 |   450/  632 batches | lr 0.00010 | ms/batch  7.74 | loss 0.00230495
# | Epoch  13 |   475/  632 batches | lr 0.00010 | ms/batch  7.89 | loss 0.00225873
# | Epoch  13 |   500/  632 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00227015
# | Epoch  13 |   525/  632 batches | lr 0.00010 | ms/batch  7.51 | loss 0.00224746
# | Epoch  13 |   550/  632 batches | lr 0.00010 | ms/batch  7.73 | loss 0.00234699
# | Epoch  13 |   575/  632 batches | lr 0.00010 | ms/batch  7.84 | loss 0.00228228
# | Epoch  13 |   600/  632 batches | lr 0.00010 | ms/batch  6.63 | loss 0.00221932
# | Epoch  13 |   625/  632 batches | lr 0.00010 | ms/batch 16.30 | loss 0.00230553
# | Epoch  14 |    25/  632 batches | lr 0.00010 | ms/batch 15.86 | loss 0.00230602
# | Epoch  14 |    50/  632 batches | lr 0.00010 | ms/batch  6.85 | loss 0.00226539
# | Epoch  14 |    75/  632 batches | lr 0.00010 | ms/batch  8.03 | loss 0.00227824
# | Epoch  14 |   100/  632 batches | lr 0.00010 | ms/batch  8.13 | loss 0.00230064
# | Epoch  14 |   125/  632 batches | lr 0.00010 | ms/batch  6.81 | loss 0.00227488
# | Epoch  14 |   150/  632 batches | lr 0.00010 | ms/batch  8.13 | loss 0.00231780
# | Epoch  14 |   175/  632 batches | lr 0.00010 | ms/batch  8.13 | loss 0.00221307
# | Epoch  14 |   200/  632 batches | lr 0.00010 | ms/batch  8.26 | loss 0.00223091
# | Epoch  14 |   225/  632 batches | lr 0.00010 | ms/batch  6.68 | loss 0.00223004
# | Epoch  14 |   250/  632 batches | lr 0.00010 | ms/batch  8.26 | loss 0.00231926
# | Epoch  14 |   275/  632 batches | lr 0.00010 | ms/batch  8.05 | loss 0.00221126
# | Epoch  14 |   300/  632 batches | lr 0.00010 | ms/batch  7.20 | loss 0.00224204
# | Epoch  14 |   325/  632 batches | lr 0.00010 | ms/batch  8.19 | loss 0.00231162
# | Epoch  14 |   350/  632 batches | lr 0.00010 | ms/batch  7.78 | loss 0.00227133
# | Epoch  14 |   375/  632 batches | lr 0.00010 | ms/batch  6.63 | loss 0.00228663
# | Epoch  14 |   400/  632 batches | lr 0.00010 | ms/batch  8.33 | loss 0.00222559
# | Epoch  14 |   425/  632 batches | lr 0.00010 | ms/batch  8.32 | loss 0.00227340
# | Epoch  14 |   450/  632 batches | lr 0.00010 | ms/batch  6.89 | loss 0.
batches | lr 0.00010 | ms/batch  6.47 | loss 0.00223575
# | Epoch  20 |   400/  632 batches | lr 0.00010 | ms/batch  7.79 | loss 0.00218207
# | Epoch  20 |   425/  632 batches | lr 0.00010 | ms/batch  7.79 | loss 0.00217585
# | Epoch  20 |   450/  632 batches | lr 0.00010 | ms/batch  6.48 | loss 0.00223658
# | Epoch  20 |   475/  632 batches | lr 0.00010 | ms/batch  7.81 | loss 0.00219225
# | Epoch  20 |   500/  632 batches | lr 0.00010 | ms/batch  8.05 | loss 0.00221243
# | Epoch  20 |   525/  632 batches | lr 0.00010 | ms/batch  7.82 | loss 0.00218355
# | Epoch  20 |   550/  632 batches | lr 0.00010 | ms/batch  6.78 | loss 0.00226465
# | Epoch  20 |   575/  632 batches | lr 0.00010 | ms/batch  7.80 | loss 0.00222685
# | Epoch  20 |   600/  632 batches | lr 0.00010 | ms/batch  7.98 | loss 0.00216842
# | Epoch  20 |   625/  632 batches | lr 0.00010 | ms/batch  6.43 | loss 0.00226431
# | Epoch  21 |    25/  632 batches | lr 0.00010 | ms/batch  8.15 | loss 0.00223150
# | Epoch  21 |    50/  632 batches | lr 0.00010 | ms/batch  7.80 | loss 0.00223064
# | Epoch  21 |    75/  632 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00222226
# | Epoch  21 |   100/  632 batches | lr 0.00010 | ms/batch  7.91 | loss 0.00222504
# | Epoch  21 |   125/  632 batches | lr 0.00010 | ms/batch  7.78 | loss 0.00224439
# | Epoch  21 |   150/  632 batches | lr 0.00010 | ms/batch  6.46 | loss 0.00218938
# | Epoch  21 |   175/  632 batches | lr 0.00010 | ms/batch  7.68 | loss 0.00214099
# | Epoch  21 |   200/  632 batches | lr 0.00010 | ms/batch  8.09 | loss 0.00216891
# | Epoch  21 |   225/  632 batches | lr 0.00010 | ms/batch  7.70 | loss 0.00216562
# | Epoch  21 |   250/  632 batches | lr 0.00010 | ms/batch  6.32 | loss 0.00223639
# | Epoch  21 |   275/  632 batches | lr 0.00010 | ms/batch  8.27 | loss 0.00215359
# | Epoch  21 |   300/  632 batches | lr 0.00010 | ms/batch  7.71 | loss 0.00218978
# | Epoch  21 |   325/  632 batches | lr 0.00010 | ms/batch  6.46 | loss 0.00224465
# | Epoch  21 |   350/  632 batches | lr 0.00010 | ms/batch  7.82 | loss 0.00218789
# | Epoch  21 |   375/  632 batches | lr 0.00010 | ms/batch  7.59 | loss 0.00222715
# | Epoch  21 |   400/  632 batches | lr 0.00010 | ms/batch  6.98 | loss 0.00217411
# | Epoch  21 |   425/  632 batches | lr 0.00010 | ms/batch  7.71 | loss 0.00216268
# | Epoch  21 |   450/  632 batches | lr 0.00010 | ms/batch  7.82 | loss 0.00222914
# | Epoch  21 |   475/  632 batches | lr 0.00010 | ms/batch  8.46 | loss 0.00218303
# | Epoch  21 |   500/  632 batches | lr 0.00010 | ms/batch  6.50 | loss 0.
batches | lr 0.00010 | ms/batch  8.21 | loss 0.00216671
# | Epoch  23 |   175/  632 batches | lr 0.00010 | ms/batch  8.64 | loss 0.00212376
# | Epoch  23 |   200/  632 batches | lr 0.00010 | ms/batch  8.43 | loss 0.00215244
# | Epoch  23 |   225/  632 batches | lr 0.00010 | ms/batch  7.07 | loss 0.00214751
# ...
# | Epoch 106 |   150/  632 batches | lr 0.00010 | ms/batch  8.55 | loss 0.00100889
# | Epoch 106 |   175/  632 batches | lr 0.00010 | ms/batch  6.71 | loss 0.00103482
# | Epoch 106 |   200/  632 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00101205
# | Epoch 106 |   225/  632 batches | lr 0.00010 | ms/batch  8.05 | loss 0.00099716
# | Epoch 106 |   250/  632 batches | lr 0.00010 | ms/batch  8.06 | loss 0.00109491
# | Epoch 106 |   275/  632 batches | lr 0.00010 | ms/batch  7.06 | loss 0.00099870
# | Epoch 106 |   300/  632 batches | lr 0.00010 | ms/batch  8.16 | loss 0.00100641
# | Epoch 106 |   325/  632 batches | lr 0.00010 | ms/batch  8.50 | loss 0.00107858
# | Epoch 106 |   350/  632 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00103171
# | Epoch 106 |   375/  632 batches | lr 0.00010 | ms/batch  8.16 | loss 0.00099564
# | Epoch 106 |   400/  632 batches | lr 0.00010 | ms/batch  8.55 | loss 0.00100839
# | Epoch 106 |   425/  632 batches | lr 0.00010 | ms/batch  6.43 | loss 0.00098251
# | Epoch 106 |   450/  632 batches | lr 0.00010 | ms/batch  8.20 | loss 0.00108439
# | Epoch 106 |   475/  632 batches | lr 0.00010 | ms/batch  8.23 | loss 0.00102720
# | Epoch 106 |   500/  632 batches | lr 0.00010 | ms/batch  7.06 | loss 0.00101177
# | Epoch 106 |   525/  632 batches | lr 0.00010 | ms/batch  8.09 | loss 0.00103556
# | Epoch 106 |   550/  632 batches | lr 0.00010 | ms/batch  7.76 | loss 0.00121566
# | Epoch 106 |   575/  632 batches | lr 0.00010 | ms/batch  7.75 | loss 0.00105452
# | Epoch 106 |   600/  632 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00098681
# | Epoch 106 |   625/  632 batches | lr 0.00010 | ms/batch  7.74 | loss 0.00100814
# | Epoch 107 |    25/  632 batches | lr 0.00010 | ms/batch  8.66 | loss 0.00104544
# | Epoch 107 |    50/  632 batches | lr 0.00010 | ms/batch  6.59 | loss 0.00102991
# | Epoch 107 |    75/  632 batches | lr 0.00010 | ms/batch  7.84 | loss 0.00101930
# | Epoch 107 |   100/  632 batches | lr 0.00010 | ms/batch  7.86 | loss 0.00099781
# | Epoch 107 |   125/  632 batches | lr 0.00010 | ms/batch  6.45 | loss 0.00103430
# | Epoch 107 |   150/  632 batches | lr 0.00010 | ms/batch  8.01 | loss 0.00099193
# | Epoch 107 |   175/  632 batches | lr 0.00010 | ms/batch  7.91 | loss 0.00102609
# | Epoch 107 |   200/  632 batches | lr 0.00010 | ms/batch  7.59 | loss 0.00099719
# | Epoch 107 |   225/  632 batches | lr 0.00010 | ms/batch  6.79 | loss 0.00098336
batches | lr 0.00010 | ms/batch  6.47 | loss 0.00102963
# | Epoch 108 |   600/  632 batches | lr 0.00010 | ms/batch  7.99 | loss 0.00095967
# | Epoch 108 |   625/  632 batches | lr 0.00010 | ms/batch  8.25 | loss 0.00098180
# | Epoch 109 |    25/  632 batches | lr 0.00010 | ms/batch  7.02 | loss 0.00102437
# | Epoch 109 |    50/  632 batches | lr 0.00010 | ms/batch  8.28 | loss 0.00101201
# | Epoch 109 |    75/  632 batches | lr 0.00010 | ms/batch  8.13 | loss 0.00101254
# | Epoch 109 |   100/  632 batches | lr 0.00010 | ms/batch  6.51 | loss 0.00098031
# | Epoch 109 |   125/  632 batches | lr 0.00010 | ms/batch  8.12 | loss 0.00102009
# | Epoch 109 |   150/  632 batches | lr 0.00010 | ms/batch  8.08 | loss 0.00096758
# | Epoch 109 |   175/  632 batches | lr 0.00010 | ms/batch  7.01 | loss 0.00100549
# | Epoch 109 |   200/  632 batches | lr 0.00010 | ms/batch  8.15 | loss 0.00097364
# | Epoch 109 |   225/  632 batches | lr 0.00010 | ms/batch  7.86 | loss 0.00095609
# | Epoch 109 |   250/  632 batches | lr 0.00010 | ms/batch  8.22 | loss 0.00105527
# | Epoch 109 |   275/  632 batches | lr 0.00010 | ms/batch  7.36 | loss 0.00096181
# | Epoch 109 |   300/  632 batches | lr 0.00010 | ms/batch  8.42 | loss 0.00096706
# | Epoch 109 |   325/  632 batches | lr 0.00010 | ms/batch  8.07 | loss 0.00102479
# | Epoch 109 |   350/  632 batches | lr 0.00010 | ms/batch  6.47 | loss 0.00097812
# | Epoch 109 |   375/  632 batches | lr 0.00010 | ms/batch  8.34 | loss 0.00096865
# | Epoch 109 |   400/  632 batches | lr 0.00010 | ms/batch  8.44 | loss 0.00098017
# | Epoch 109 |   425/  632 batches | lr 0.00010 | ms/batch  6.93 | loss 0.00095414
# | Epoch 109 |   450/  632 batches | lr 0.00010 | ms/batch  8.15 | loss 0.00105142
# | Epoch 109 |   475/  632 batches | lr 0.00010 | ms/batch  8.35 | loss 0.00099205
# | Epoch 109 |   500/  632 batches | lr 0.00010 | ms/batch  6.91 | loss 0.00097802
# | Epoch 109 |   525/  632 batches | lr 0.00010 | ms/batch  8.03 | loss 0.00101850
# | Epoch 109 |   550/  632 batches | lr 0.00010 | ms/batch  8.21 | loss 0.00118472
# | Epoch 109 |   575/  632 batches | lr 0.00010 | ms/batch  8.42 | loss 0.00101925
# | Epoch 109 |   600/  632 batches | lr 0.00010 | ms/batch  6.67 | loss 0.00094883
# | Epoch 109 |   625/  632 batches | lr 0.00010 | ms/batch  8.06 | loss 0.00097090
# | Epoch 110 |    25/  632 batches | lr 0.00010 | ms/batch  8.11 | loss 0.00101467
# | Epoch 110 |    50/  632 batches | lr 0.00010 | ms/batch  6.83 | loss 0.00100165
# | Epoch 110 |    75/  632 batches | lr 0.00010 | ms/batch  8.50 | loss 0.00100230
# | Epoch 110 |   100/  632 batches | lr 0.00010 | ms/batch  8.18 | loss 0.00097050
# | Epoch 110 |   125/  632 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00100983
# | Epoch 110 |   150/  632 batches | lr 0.00010 | ms/batch  8.15 | loss 0.00095692
# | Epoch 110 |   175/  632 batches | lr 0.00010 | ms/batch  7.63 | loss 0.00099722
# | Epoch 110 |   200/  632 batches | lr 0.00010 | ms/batch  7.82 | loss 0.00095888
# | Epoch 110 |   225/  632 batches | lr 0.00010 | ms/batch  6.44 | loss 0.00094261
# | Epoch 110 |   250/  632 batches | lr 0.00010 | ms/batch  7.91 | loss 0.00103535
# | Epoch 110 |   275/  632 batches | lr 0.00010 | ms/batch  8.02 | loss 0.00094729
# | Epoch 110 |   300/  632 batches | lr 0.00010 | ms/batch  6.97 | loss 0.00095493
# | Epoch 110 |   325/  632 batches | lr 0.00010 | ms/batch  8.12 | loss 0.00100829
# | Epoch 110 |   350/  632 batches | lr 0.00010 | ms/batch  8.25 | loss 0.00096114
# | Epoch 110 |   375/  632 batches | lr 0.00010 | ms/batch  6.70 | loss 0.00095825
# | Epoch 110 |   400/  632 batches | lr 0.00010 | ms/batch  8.03 | loss 0.00096923
# | Epoch 110 |   425/  632 batches | lr 0.00010 | ms/batch  7.89 | loss 0.00094640
# | Epoch 110 |   450/  632 batches | lr 0.00010 | ms/batch  6.99 | loss 0.00104267
# | Epoch 110 |   475/  632 batches | lr 0.00010 | ms/batch  8.64 | loss 0.00098281
# | Epoch 110 |   500/  632 batches | lr 0.00010 | ms/batch  8.21 | loss 0.00097103
# | Epoch 110 |   525/  632 batches | lr 0.00010 | ms/batch  7.93 | loss 0.00100996
# | Epoch 110 |   550/  632 batches | lr 0.00010 | ms/batch  6.92 | loss 0.00116861
# | Epoch 110 |   575/  632 batches | lr 0.00010 | ms/batch  7.96 | loss 0.00100618
# | Epoch 110 |   600/  632 batches | lr 0.00010 | ms/batch  7.90 | loss 0.00093969
# | Epoch 110 |   625/  632 batches | lr 0.00010 | ms/batch  6.52 | loss 0.00095718
# | Epoch 111 |    25/  632 batches | lr 0.00010 | ms/batch  8.67 | loss 0.00100442
# | Epoch 111 |    50/  632 batches | lr 0.00010 | ms/batch  8.05 | loss 0.00099216
# | Epoch 111 |    75/  632 batches | lr 0.00010 | ms/batch  6.45 | loss 0.00099699
# | Epoch 111 |   100/  632 batches | lr 0.00010 | ms/batch  7.96 | loss 0.00096200
# | Epoch 111 |   125/  632 batches | lr 0.00010 | ms/batch  7.65 | loss 0.00099634
# | Epoch 111 |   150/  632 batches | lr 0.00010 | ms/batch  6.69 | loss 0.00094657
# | Epoch 111 |   175/  632 batches | lr 0.00010 | ms/batch  7.60 | loss 0.00099282
# | Epoch 111 |   200/  632 batches | lr 0.00010 | ms/batch  7.69 | loss 0.00095168
# | Epoch 111 |   225/  632 batches | lr 0.00010 | ms/batch  7.77 | loss 0.00093338
# | Epoch 111 |   250/  632 batches | lr 0.00010 | ms/batch  6.45 | loss 0.00102132
# | Epoch 111 |   275/  632 batches | lr 0.00010 | ms/batch  7.86 | loss 0.00093736
# | Epoch 111 |   300/  632 batches | lr 0.00010 | ms/batch  7.84 | loss 0.
# | Epoch 112 |   525/  632 batches | lr 0.00010 | ms/batch  8.65 | loss 0.00099467
# | Epoch 112 |   550/  632 batches | lr 0.00010 | ms/batch  8.31 | loss 0.00114500
# | Epoch 112 |   575/  632 batches | lr 0.00010 | ms/batch  8.31 | loss 0.00098538
# | Epoch 112 |   600/  632 batches | lr 0.00010 | ms/batch  7.39 | loss 0.00092057
# | Epoch 112 |   625/  632 batches | lr 0.00010 | ms/batch  8.32 | loss 0.00093591
# | Epoch 113 |    25/  632 batches | lr 0.00010 | ms/batch  8.45 | loss 0.00098450
# | Epoch 113 |    50/  632 batches | lr 0.00010 | ms/batch  6.62 | loss 0.00097609
# | Epoch 113 |    75/  632 batches | lr 0.00010 | ms/batch  8.11 | loss 0.00098076
# | Epoch 113 |   100/  632 batches | lr 0.00010 | ms/batch  8.19 | loss 0.00094133
# | Epoch 113 |   125/  632 batches | lr 0.00010 | ms/batch  6.75 | loss 0.00097908
# | Epoch 113 |   150/  632 batches | lr 0.00010 | ms/batch  8.42 | loss 0.00091974
# | Epoch 113 |   175/  632 batches | lr 0.00010 | ms/batch  7.75 | loss 0.00096436
# | Epoch 113 |   200/  632 batches | lr 0.00010 | ms/batch  8.00 | loss 0.00092191
# | Epoch 113 |   225/  632 batches | lr 0.00010 | ms/batch  7.25 | loss 0.00091023
# | Epoch 113 |   250/  632 batches | lr 0.00010 | ms/batch  8.01 | loss 0.00099403
# | Epoch 113 |   275/  632 batches | lr 0.00010 | ms/batch  8.36 | loss 0.00091386
# | Epoch 113 |   300/  632 batches | lr 0.00010 | ms/batch  6.55 | loss 0.00092251
# | Epoch 113 |   325/  632 batches | lr 0.00010 | ms/batch  7.83 | loss 0.00096565
# | Epoch 113 |   350/  632 batches | lr 0.00010 | ms/batch  8.26 | loss 0.00093194
# | Epoch 113 |   375/  632 batches | lr 0.00010 | ms/batch  6.61 | loss 0.00092635
# | Epoch 113 |   400/  632 batches | lr 0.00010 | ms/batch  8.17 | loss 0.00093537
# | Epoch 113 |   425/  632 batches | lr 0.00010 | ms/batch  8.24 | loss 0.00091881
# | Epoch 113 |   450/  632 batches | lr 0.00010 | ms/batch  6.58 | loss 0.00102472
# | Epoch 113 |   475/  632 batches | lr 0.00010 | ms/batch  7.89 | loss 0.00095078
# | Epoch 113 |   500/  632 batches | lr 0.00010 | ms/batch  7.25 | loss 0.00094295
# | Epoch 113 |   525/  632 batches | lr 0.00010 | ms/batch  7.62 | loss 0.00098214
# | Epoch 113 |   550/  632 batches | lr 0.00010 | ms/batch  6.50 | loss 0.00112956
# | Epoch 113 |   575/  632 batches | lr 0.00010 | ms/batch  7.62 | loss 0.00097525
# | Epoch 113 |   600/  632 batches | lr 0.00010 | ms/batch  7.74 | loss 0.00091289
# | Epoch 113 |   625/  632 batches | lr 0.00010 | ms/batch  6.60 | loss 0.00092582

# %%
testing_results

# %%
testing_results.to_csv('/content/drive/MyDrive/Progetto Stage/results/testing_results_heston.csv')
